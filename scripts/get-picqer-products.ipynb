# %%
import requests
import json
import re

# %%
BASE_URL = "http://2cheapbv.picqer.com"
USERNAME = "webshopimporter"
PASSWORD = "wdbT4zIUhQ@"
API_KEY = "xhDM2BVsiMzgcUkJAX08RpymByC1oQF1zreynUOMPxUX7Vc9"

# %%
with open("lightspeed_variants.json", "r") as f:
    all_variants = json.load(f)

# %%
print(json.dumps(all_variants[1000], indent=2))
# Out:
# {
#   "id": 319155756,
#   "createdAt": "2026-01-06T14:09:16+01:00",
#   "updatedAt": "2026-01-07T01:15:23+01:00",
#   "isDefault": true,
#   "sortOrder": 1,
#   "articleCode": "CYT-0578",
#   "ean": "8718347831189",
#   "sku": "24327039331",
#   "hs": null,
#   "unitPrice": 0,
#   "unitUnit": null,
#   "priceExcl": 39.6281,
#   "priceIncl": 47.95,
#   "priceCost": 17.46,
#   "oldPriceExcl": 0,
#   "oldPriceIncl": 0,
#   "stockTracking": "enabled",
#   "stockLevel": 0,
#   "stockAlert": 0,
#   "stockMinimum": 0,
#   "stockSold": 0,
#   "stockBuyMininum": 1,
#   "stockBuyMinimum": 1,
#   "stockBuyMaximum": 10000,
#   "weight": 25,
#   "weightValue": "25.000",
#   "weightUnit": "g",
#   "volume": 0,
#   "volumeValue": 0,
#   "volumeUnit": "ml",
#   "colli": 0,
#   "sizeX": 0,
#   "sizeY": 0,
#   "sizeZ": 0,
#   "sizeXValue": null,
#   "sizeYValue": null,
#   "sizeZValue": null,
#   "sizeUnit": "cm",
#   "matrix": false,
#   "title": "Default",
#   "taxType": null,
#   "image": false,
#   "tax": {
#     "resource": {
#       "id": 48606,
#       "url": "taxes/48606",
#       "link": "https://api.webshopapp.com/nl/taxes/48606.json"
#     }
#   },
#   "product": {
#     "resource": {
#       "id": 161174702,
#       "url": "products/161174702",
#       "link": "https://api.webshopapp.com/nl/products/161174702.json"
#     }
#   },
#   "movements": {
#     "resource": {
#       "id": false,
#       "url": "variants/movements?variant=319155756",
#       "link": "https://api.webshopapp.com/nl/variants/movements.json?variant=319155756"
#     }
#   },
#   "metafields": {
#     "resource": {
#       "id": false,
#       "url": "variants/319155756/metafields",
#       "link": "https://api.webshopapp.com/nl/variants/319155756/metafields.json"
#     }
#   },
#   "additionalcost": false,
#   "options": [],
#   "product_title": "BE1202A Kettingwiel Race 52/42 352463 - aluminium - 4 mm - zilver - voor fietsgebruik - aantal 9 versnellingen",
#   "product_fulltitle": "Falkx BE1202A Kettingwiel Race 52/42 352463",
#   "product_description": "BE1202A Kettingwiel Race 52/42 352463 voor fietsgebruik met aluminium, 4 mm, zilver, aantal 9 versnellingen voor comfortabel en veilig gebruik.",
#   "product_content": "<h4>Ontdek de BE1202A Kettingwiel Race 52/42 352463 - aluminium - 4 mm - zilver - voor fietsgebruik - aantal 9 versnellingen</h4><p>BE1202A Kettingwiel Race 52/42 352463 is gemaakt voor fietsgebruik en helpt je gericht en gecontroleerd te werken. Belangrijkste maat: 4 mm.</p><h4>Materiaal en afmetingen</h4><p>Het materiaal (aluminium) is gekozen voor stevig gebruik en een betrouwbare grip. De kleur zilver zorgt voor een neutrale en herkenbare uitstraling. Specificaties in het kort: aantal 9 versnellingen, aantal 52.</p><h4>Toepassing en gebruik</h4><p>Geschikt voor toepassingen waarbij maatvoering, materiaal en functies het verschil maken. Extra specificatie: aantal 42.</p><h4>Kenmerken</h4><ul><li><strong>Merk:</strong> Falkx</li><li><strong>Productgroep:</strong> BE1202A Kettingwiel Race 52/42 352463</li><li><strong>Materiaal:</strong> aluminium</li><li><strong>Kleur:</strong> zilver</li><li><strong>Maat:</strong> 4 mm</li><li><strong>Aantal versnellingen achter:</strong> 9 versnellingen</li><li><strong>Aantal tanden blad 1:</strong> 52</li><li><strong>Aantal tanden blad 2:</strong> 42</li><li><strong>Bevestiging:</strong> Vierkant</li><li><strong>Lengte:</strong> 170</li><li><strong>Versnellingen:</strong> 9-speed</li></ul><h4>Gebruikstip</h4><p>Gebruik de kenmerken hierboven om de juiste maat en uitvoering te kiezen voor jouw toepassing.</p><h4>Zoekwoorden</h4><p><strong>Zoekwoorden:</strong> be1202a kettingwiel race 52/42 352463, aluminium, zilver, 4 mm, fiets</p>",
#   "product_data01": "Op voorraad bij leverancier, levertijd: 3-5 dagen"
# }

# %%
# Get picqer productfields
response = requests.get(f"{BASE_URL}/api/v1/productfields", auth=(API_KEY, ""))
product_fields = response.json()
print(json.dumps(product_fields, indent=2))

with open('picqer_productfields.json', 'w') as f:
    json.dump(product_fields, f, indent=2)
# Out:
# [
#   {
#     "idproductfield": 360,
#     "title": "Beschikbaar",
#     "type": "select",
#     "values": [
#       "LEVERTIJD",
#       ""
#     ],
#     "required": false,
#     "visible_picklist": false,
#     "visible_invoice": false,
#     "visible_shippinglist": false,
#     "visible_portal": false,
#     "visible_purchase_order": true,
#     "visible_receipt": true
#   },
#   {
#     "idproductfield": 5745,
#     "title": "Beschikbaar - Aangemaakt op",
#     "type": "text",
#     "values": [],
#     "required": false,
#     "visible_picklist": false,
#     "visible_invoice": false,
#     "visible_shippinglist": false,
#     "visible_portal": true,
#     "visible_purchase_order": true,
#     "visible_receipt": false
#   },
#   {
#     "idproductfield": 253,
#     "title": "Opmerking Inkoop",
#     "type": "text",
#     "values": [],
#     "required": false,
#     "visible_picklist": false,
#     "visible_invoice": false,
#     "visible_shippinglist": false,
#     "visible_portal": false,
#     "visible_purchase_order": true,
#     "visible_receipt": true
#   },
#   {
#     "idproductfield": 448,
#     "title": "Opmerking Picking",
#     "type": "text",
#     "values": [],
#     "required": false,
#     "visible_picklist": true,
#     "visible_invoice": false,
#     "visible_shippinglist": false,
#     "visible_portal": true,
#     "visible_purchase_order": false,
#     "visible_receipt": false
#   },
#   {
#     "idproductfield": 5156,
#     "title": "Staffel",
#     "type": "text",
#     "values": [],
#     "required": false,
#     "visible_picklist": false,
#     "visible_invoice": false,
#     "visible_shippinglist": false,
#     "visible_portal": false,
#     "visible_purchase_order": true,
#     "visible_receipt": true
#   },
#   {
#     "idproductfield": 1079,
#     "title": "Verzend",
#     "type": "radio",
#     "values": [
#       "Briefpost",
#       "DHL Small",
#       "DPD",
#       "DHL XXL",
#       "Speciaal Transport",
#       "VERZENDTYPE ONBEKEND"
#     ],
#     "required": false,
#     "visible_picklist": true,
#     "visible_invoice": false,
#     "visible_shippinglist": false,
#     "visible_portal": true,
#     "visible_purchase_order": false,
#     "visible_receipt": true
#   },
#   {
#     "idproductfield": 3223,
#     "title": "VPE",
#     "type": "text",
#     "values": [],
#     "required": false,
#     "visible_picklist": false,
#     "visible_invoice": false,
#     "visible_shippinglist": false,
#     "visible_portal": false,
#     "visible_purchase_order": true,
#     "visible_receipt": true
#   },
#   {
#     "idproductfield": 5746,
#     "title": "X",
#     "type": "text",
#     "values": [],
#     "required": false,
#     "visible_picklist": false,
#     "visible_invoice": false,
#     "visible_shippinglist": false,
#     "visible_portal": false,
#     "visible_purchase_order": true,
#     "visible_receipt": true
#   }
# ]

# %%
# Get picqer tags
response = requests.get(f"{BASE_URL}/api/v1/tags", auth=(API_KEY, ""))
tags = response.json()
print(json.dumps(tags, indent=2))

with open('picqer_tags.json', 'w') as f:
    json.dump(tags, f, indent=2)
# Out:
# [
#   {
#     "idtag": 8666,
#     "title": "2Cheap",
#     "color": "#43c059",
#     "inherit": true,
#     "textColor": "#000000"
#   },
#   {
#     "idtag": 64272,
#     "title": "AFHAAL",
#     "color": "#f000cf",
#     "inherit": false,
#     "textColor": "#000000"
#   },
#   {
#     "idtag": 25613,
#     "title": "Bol BE",
#     "color": "#d0d0dd",
#     "inherit": false,
#     "textColor": "#000000"
#   },
#   {
#     "idtag": 27013,
#     "title": "Bol NL",
#     "color": "#2929a3",
#     "inherit": true,
#     "textColor": "#FFFFFF"
#   },
#   {
#     "idtag": 8125,
#     "title": "Briefpost",
#     "color": "#1aa8b0",
#     "inherit": true,
#     "textColor": "#000000"
#   },
#   {
#     "idtag": 11964,
#     "title": "DHL Small",
#     "color": "#0000f0",
#     "inherit": true,
#     "textColor": "#FFFFFF"
#   },
#   {
#     "idtag": 18778,
#     "title": "DHL XXL",
#     "color": "#2e8b82",
#     "inherit": true,
#     "textColor": "#FFFFFF"
#   },
#   {
#     "idtag": 17307,
#     "title": "DPD",
#     "color": "#e5f000",
#     "inherit": false,
#     "textColor": "#000000"
#   },
#   {
#     "idtag": 235835,
#     "title": "Duitsland",
#     "color": "#ffb700",
#     "inherit": true,
#     "textColor": "#000000"
#   },
#   {
#     "idtag": 140092,
#     "title": "IN3/BILLINK",
#     "color": "#d4f000",
#     "inherit": false,
#     "textColor": "#000000"
#   },
#   {
#     "idtag": 106828,
#     "title": "Keukenmesjes.nl",
#     "color": "#ec2b40",
#     "inherit": true,
#     "textColor": "#000000"
#   },
#   {
#     "idtag": 11033,
#     "title": "Speciaal Transport",
#     "color": "#c7b6d8",
#     "inherit": true,
#     "textColor": "#000000"
#   },
#   {
#     "idtag": 153905,
#     "title": "VERZENDTYPE ONBEKEND",
#     "color": "#f00600",
#     "inherit": false,
#     "textColor": "#000000"
#   },
#   {
#     "idtag": 235837,
#     "title": "YAXELL Q1 2025 ACTIE",
#     "color": "#000000",
#     "inherit": false,
#     "textColor": "#FFFFFF"
#   }
# ]

# %%
send_options_field = [product_field for product_field in product_fields if product_field["title"] == "Verzend"][0]
available_created_at_field = [product_field for product_field in product_fields if product_field["title"] == "Beschikbaar - Aangemaakt op"][0]

# %%
# Get all products
product_url = f"{BASE_URL}/api/v1/products"
all_products = []
offset = 0

while product_url:
    response = requests.get(f"{product_url}?offset={offset}", auth=(API_KEY, ""))
    products = response.json()

    all_products.extend(products)
    print(f"Retrieved {len(products)} products, total so far: {len(all_products)}")

    if len(products) < 100:
        break

    offset = len(all_products)
# Out:
# Retrieved 100 products, total so far: 100
# Retrieved 100 products, total so far: 200
# Retrieved 100 products, total so far: 300
# Retrieved 100 products, total so far: 400
# Retrieved 100 products, total so far: 500
# Retrieved 100 products, total so far: 600
# Retrieved 100 products, total so far: 700
# Retrieved 100 products, total so far: 800
# Retrieved 100 products, total so far: 900
# Retrieved 100 products, total so far: 1000
# Retrieved 100 products, total so far: 1100
# Retrieved 100 products, total so far: 1200
# Retrieved 100 products, total so far: 1300
# Retrieved 100 products, total so far: 1400
# Retrieved 100 products, total so far: 1500
# Retrieved 100 products, total so far: 1600
# Retrieved 100 products, total so far: 1700
# Retrieved 100 products, total so far: 1800
# Retrieved 100 products, total so far: 1900
# Retrieved 100 products, total so far: 2000
# Retrieved 100 products, total so far: 2100
# Retrieved 100 products, total so far: 2200
# Retrieved 100 products, total so far: 2300
# Retrieved 100 products, total so far: 2400
# Retrieved 100 products, total so far: 2500
# Retrieved 100 products, total so far: 2600
# Retrieved 100 products, total so far: 2700
# Retrieved 100 products, total so far: 2800
# Retrieved 100 products, total so far: 2900
# Retrieved 100 products, total so far: 3000
# Retrieved 100 products, total so far: 3100
# Retrieved 100 products, total so far: 3200
# Retrieved 100 products, total so far: 3300
# Retrieved 100 products, total so far: 3400
# Retrieved 100 products, total so far: 3500
# Retrieved 100 products, total so far: 3600
# Retrieved 100 products, total so far: 3700
# Retrieved 100 products, total so far: 3800
# Retrieved 100 products, total so far: 3900
# Retrieved 100 products, total so far: 4000
# Retrieved 100 products, total so far: 4100
# Retrieved 100 products, total so far: 4200
# Retrieved 100 products, total so far: 4300
# Retrieved 100 products, total so far: 4400
# Retrieved 100 products, total so far: 4500
# Retrieved 100 products, total so far: 4600
# Retrieved 100 products, total so far: 4700
# Retrieved 100 products, total so far: 4800
# Retrieved 100 products, total so far: 4900
# Retrieved 100 products, total so far: 5000
# Retrieved 100 products, total so far: 5100
# Retrieved 100 products, total so far: 5200
# Retrieved 100 products, total so far: 5300
# Retrieved 100 products, total so far: 5400
# Retrieved 100 products, total so far: 5500
# Retrieved 100 products, total so far: 5600
# Retrieved 100 products, total so far: 5700
# Retrieved 100 products, total so far: 5800
# Retrieved 100 products, total so far: 5900
# Retrieved 100 products, total so far: 6000
# Retrieved 100 products, total so far: 6100
# Retrieved 100 products, total so far: 6200
# Retrieved 100 products, total so far: 6300
# Retrieved 100 products, total so far: 6400
# Retrieved 100 products, total so far: 6500
# Retrieved 100 products, total so far: 6600
# Retrieved 100 products, total so far: 6700
# Retrieved 100 products, total so far: 6800
# Retrieved 100 products, total so far: 6900
# Retrieved 100 products, total so far: 7000
# Retrieved 100 products, total so far: 7100
# Retrieved 100 products, total so far: 7200
# Retrieved 100 products, total so far: 7300
# Retrieved 100 products, total so far: 7400
# Retrieved 100 products, total so far: 7500
# Retrieved 100 products, total so far: 7600
# Retrieved 100 products, total so far: 7700
# Retrieved 100 products, total so far: 7800
# Retrieved 100 products, total so far: 7900
# Retrieved 100 products, total so far: 8000
# Retrieved 100 products, total so far: 8100
# Retrieved 100 products, total so far: 8200
# Retrieved 100 products, total so far: 8300
# Retrieved 100 products, total so far: 8400
# Retrieved 100 products, total so far: 8500
# Retrieved 100 products, total so far: 8600
# Retrieved 100 products, total so far: 8700
# Retrieved 100 products, total so far: 8800
# Retrieved 100 products, total so far: 8900
# Retrieved 100 products, total so far: 9000
# Retrieved 100 products, total so far: 9100
# Retrieved 100 products, total so far: 9200
# Retrieved 100 products, total so far: 9300
# Retrieved 100 products, total so far: 9400
# Retrieved 100 products, total so far: 9500
# Retrieved 100 products, total so far: 9600
# Retrieved 100 products, total so far: 9700
# Retrieved 100 products, total so far: 9800
# Retrieved 100 products, total so far: 9900
# Retrieved 100 products, total so far: 10000
# Retrieved 100 products, total so far: 10100
# Retrieved 100 products, total so far: 10200
# Retrieved 100 products, total so far: 10300
# Retrieved 100 products, total so far: 10400
# Retrieved 100 products, total so far: 10500
# Retrieved 100 products, total so far: 10600
# Retrieved 100 products, total so far: 10700
# Retrieved 100 products, total so far: 10800
# Retrieved 100 products, total so far: 10900
# Retrieved 100 products, total so far: 11000
# Retrieved 100 products, total so far: 11100
# Retrieved 100 products, total so far: 11200
# Retrieved 100 products, total so far: 11300
# Retrieved 100 products, total so far: 11400
# Retrieved 100 products, total so far: 11500
# Retrieved 100 products, total so far: 11600
# Retrieved 100 products, total so far: 11700
# Retrieved 100 products, total so far: 11800
# Retrieved 100 products, total so far: 11900
# Retrieved 100 products, total so far: 12000
# Retrieved 100 products, total so far: 12100
# Retrieved 100 products, total so far: 12200
# Retrieved 100 products, total so far: 12300
# Retrieved 100 products, total so far: 12400
# Retrieved 100 products, total so far: 12500
# Retrieved 100 products, total so far: 12600
# Retrieved 100 products, total so far: 12700
# Retrieved 100 products, total so far: 12800
# Retrieved 100 products, total so far: 12900
# Retrieved 100 products, total so far: 13000
# Retrieved 100 products, total so far: 13100
# Retrieved 100 products, total so far: 13200
# Retrieved 100 products, total so far: 13300
# Retrieved 100 products, total so far: 13400
# Retrieved 100 products, total so far: 13500
# Retrieved 100 products, total so far: 13600
# Retrieved 100 products, total so far: 13700
# Retrieved 100 products, total so far: 13800
# Retrieved 100 products, total so far: 13900
# Retrieved 100 products, total so far: 14000
# Retrieved 100 products, total so far: 14100
# Retrieved 100 products, total so far: 14200
# Retrieved 100 products, total so far: 14300
# Retrieved 100 products, total so far: 14400
# Retrieved 100 products, total so far: 14500
# Retrieved 100 products, total so far: 14600
# Retrieved 100 products, total so far: 14700
# Retrieved 100 products, total so far: 14800
# Retrieved 100 products, total so far: 14900
# Retrieved 100 products, total so far: 15000
# Retrieved 100 products, total so far: 15100
# Retrieved 100 products, total so far: 15200
# Retrieved 100 products, total so far: 15300
# Retrieved 100 products, total so far: 15400
# Retrieved 100 products, total so far: 15500
# Retrieved 100 products, total so far: 15600
# Retrieved 100 products, total so far: 15700
# Retrieved 100 products, total so far: 15800
# Retrieved 100 products, total so far: 15900
# Retrieved 100 products, total so far: 16000
# Retrieved 100 products, total so far: 16100
# Retrieved 100 products, total so far: 16200
# Retrieved 100 products, total so far: 16300
# Retrieved 100 products, total so far: 16400
# Retrieved 100 products, total so far: 16500
# Retrieved 100 products, total so far: 16600
# Retrieved 100 products, total so far: 16700
# Retrieved 100 products, total so far: 16800
# Retrieved 100 products, total so far: 16900
# Retrieved 100 products, total so far: 17000
# Retrieved 100 products, total so far: 17100
# Retrieved 100 products, total so far: 17200
# Retrieved 100 products, total so far: 17300
# Retrieved 100 products, total so far: 17400
# Retrieved 100 products, total so far: 17500
# Retrieved 100 products, total so far: 17600
# Retrieved 100 products, total so far: 17700
# Retrieved 100 products, total so far: 17800
# Retrieved 100 products, total so far: 17900
# Retrieved 100 products, total so far: 18000
# Retrieved 100 products, total so far: 18100
# Retrieved 100 products, total so far: 18200
# Retrieved 100 products, total so far: 18300
# Retrieved 100 products, total so far: 18400
# Retrieved 100 products, total so far: 18500
# Retrieved 100 products, total so far: 18600
# Retrieved 100 products, total so far: 18700
# Retrieved 100 products, total so far: 18800
# Retrieved 100 products, total so far: 18900
# Retrieved 100 products, total so far: 19000
# Retrieved 100 products, total so far: 19100
# Retrieved 100 products, total so far: 19200
# Retrieved 100 products, total so far: 19300
# Retrieved 100 products, total so far: 19400
# Retrieved 100 products, total so far: 19500
# Retrieved 100 products, total so far: 19600
# Retrieved 100 products, total so far: 19700
# Retrieved 100 products, total so far: 19800
# Retrieved 100 products, total so far: 19900
# Retrieved 100 products, total so far: 20000
# Retrieved 100 products, total so far: 20100
# Retrieved 100 products, total so far: 20200
# Retrieved 100 products, total so far: 20300
# Retrieved 100 products, total so far: 20400
# Retrieved 100 products, total so far: 20500
# Retrieved 100 products, total so far: 20600
# Retrieved 100 products, total so far: 20700
# Retrieved 100 products, total so far: 20800
# Retrieved 100 products, total so far: 20900
# Retrieved 100 products, total so far: 21000
# Retrieved 100 products, total so far: 21100
# Retrieved 100 products, total so far: 21200
# Retrieved 100 products, total so far: 21300
# Retrieved 100 products, total so far: 21400
# Retrieved 100 products, total so far: 21500
# Retrieved 100 products, total so far: 21600
# Retrieved 100 products, total so far: 21700
# Retrieved 100 products, total so far: 21800
# Retrieved 100 products, total so far: 21900
# Retrieved 100 products, total so far: 22000
# Retrieved 100 products, total so far: 22100
# Retrieved 100 products, total so far: 22200
# Retrieved 100 products, total so far: 22300
# Retrieved 100 products, total so far: 22400
# Retrieved 100 products, total so far: 22500
# Retrieved 100 products, total so far: 22600
# Retrieved 100 products, total so far: 22700
# Retrieved 100 products, total so far: 22800
# Retrieved 100 products, total so far: 22900
# Retrieved 100 products, total so far: 23000
# Retrieved 100 products, total so far: 23100
# Retrieved 100 products, total so far: 23200
# Retrieved 100 products, total so far: 23300
# Retrieved 100 products, total so far: 23400
# Retrieved 100 products, total so far: 23500
# Retrieved 100 products, total so far: 23600
# Retrieved 100 products, total so far: 23700
# Retrieved 100 products, total so far: 23800
# Retrieved 100 products, total so far: 23900
# Retrieved 100 products, total so far: 24000
# Retrieved 100 products, total so far: 24100
# Retrieved 100 products, total so far: 24200
# Retrieved 100 products, total so far: 24300
# Retrieved 100 products, total so far: 24400
# Retrieved 100 products, total so far: 24500
# Retrieved 100 products, total so far: 24600
# Retrieved 100 products, total so far: 24700
# Retrieved 100 products, total so far: 24800
# Retrieved 100 products, total so far: 24900
# Retrieved 100 products, total so far: 25000
# Retrieved 100 products, total so far: 25100
# Retrieved 100 products, total so far: 25200
# Retrieved 100 products, total so far: 25300
# Retrieved 100 products, total so far: 25400
# Retrieved 100 products, total so far: 25500
# Retrieved 100 products, total so far: 25600
# Retrieved 100 products, total so far: 25700
# Retrieved 100 products, total so far: 25800
# Retrieved 100 products, total so far: 25900
# Retrieved 100 products, total so far: 26000
# Retrieved 100 products, total so far: 26100
# Retrieved 100 products, total so far: 26200
# Retrieved 100 products, total so far: 26300
# Retrieved 100 products, total so far: 26400
# Retrieved 100 products, total so far: 26500
# Retrieved 100 products, total so far: 26600
# Retrieved 100 products, total so far: 26700
# Retrieved 100 products, total so far: 26800
# Retrieved 100 products, total so far: 26900
# Retrieved 100 products, total so far: 27000
# Retrieved 100 products, total so far: 27100
# Retrieved 100 products, total so far: 27200
# Retrieved 100 products, total so far: 27300
# Retrieved 100 products, total so far: 27400
# Retrieved 100 products, total so far: 27500
# Retrieved 100 products, total so far: 27600
# Retrieved 100 products, total so far: 27700
# Retrieved 100 products, total so far: 27800
# Retrieved 100 products, total so far: 27900
# Retrieved 100 products, total so far: 28000
# Retrieved 100 products, total so far: 28100
# Retrieved 100 products, total so far: 28200
# Retrieved 100 products, total so far: 28300
# Retrieved 100 products, total so far: 28400
# Retrieved 100 products, total so far: 28500
# Retrieved 100 products, total so far: 28600
# Retrieved 100 products, total so far: 28700
# Retrieved 100 products, total so far: 28800
# Retrieved 100 products, total so far: 28900
# Retrieved 100 products, total so far: 29000
# Retrieved 100 products, total so far: 29100
# Retrieved 100 products, total so far: 29200
# Retrieved 100 products, total so far: 29300
# Retrieved 100 products, total so far: 29400
# Retrieved 100 products, total so far: 29500
# Retrieved 100 products, total so far: 29600
# Retrieved 100 products, total so far: 29700
# Retrieved 100 products, total so far: 29800
# Retrieved 100 products, total so far: 29900
# Retrieved 100 products, total so far: 30000
# Retrieved 100 products, total so far: 30100
# Retrieved 100 products, total so far: 30200
# Retrieved 100 products, total so far: 30300
# Retrieved 100 products, total so far: 30400
# Retrieved 100 products, total so far: 30500
# Retrieved 100 products, total so far: 30600
# Retrieved 100 products, total so far: 30700
# Retrieved 100 products, total so far: 30800
# Retrieved 100 products, total so far: 30900
# Retrieved 100 products, total so far: 31000
# Retrieved 100 products, total so far: 31100
# Retrieved 100 products, total so far: 31200
# Retrieved 100 products, total so far: 31300
# Retrieved 100 products, total so far: 31400
# Retrieved 100 products, total so far: 31500
# Retrieved 100 products, total so far: 31600
# Retrieved 100 products, total so far: 31700
# Retrieved 100 products, total so far: 31800
# Retrieved 100 products, total so far: 31900
# Retrieved 100 products, total so far: 32000
# Retrieved 100 products, total so far: 32100
# Retrieved 100 products, total so far: 32200
# Retrieved 100 products, total so far: 32300
# Retrieved 100 products, total so far: 32400
# Retrieved 100 products, total so far: 32500
# Retrieved 100 products, total so far: 32600
# Retrieved 100 products, total so far: 32700
# Retrieved 100 products, total so far: 32800
# Retrieved 100 products, total so far: 32900
# Retrieved 100 products, total so far: 33000
# Retrieved 100 products, total so far: 33100
# Retrieved 100 products, total so far: 33200
# Retrieved 100 products, total so far: 33300
# Retrieved 100 products, total so far: 33400
# Retrieved 100 products, total so far: 33500
# Retrieved 100 products, total so far: 33600
# Retrieved 100 products, total so far: 33700
# Retrieved 100 products, total so far: 33800
# Retrieved 100 products, total so far: 33900
# Retrieved 100 products, total so far: 34000
# Retrieved 100 products, total so far: 34100
# Retrieved 100 products, total so far: 34200
# Retrieved 100 products, total so far: 34300
# Retrieved 100 products, total so far: 34400
# Retrieved 100 products, total so far: 34500
# Retrieved 100 products, total so far: 34600
# Retrieved 100 products, total so far: 34700
# Retrieved 100 products, total so far: 34800
# Retrieved 100 products, total so far: 34900
# Retrieved 100 products, total so far: 35000
# Retrieved 100 products, total so far: 35100
# Retrieved 100 products, total so far: 35200
# Retrieved 100 products, total so far: 35300
# Retrieved 100 products, total so far: 35400
# Retrieved 100 products, total so far: 35500
# Retrieved 100 products, total so far: 35600
# Retrieved 100 products, total so far: 35700
# Retrieved 100 products, total so far: 35800
# Retrieved 100 products, total so far: 35900
# Retrieved 100 products, total so far: 36000
# Retrieved 100 products, total so far: 36100
# Retrieved 100 products, total so far: 36200
# Retrieved 100 products, total so far: 36300
# Retrieved 100 products, total so far: 36400
# Retrieved 69 products, total so far: 36469

# %%
with open('picqer_products.json', 'w') as f:
    json.dump(all_products, f, indent=2)

# %%
print(json.dumps(all_products[200], indent=2))
# Out:
# {
#   "idproduct": 1822862,
#   "idvatgroup": 3583,
#   "idsupplier": 11409,
#   "productcode": "24327000233",
#   "name": "Benson Extra dikke vuilniszakken - 120 liter - 29 micron - 10 stuks - Grijs",
#   "price": 2.89,
#   "fixedstockprice": 1.35,
#   "productcode_supplier": "BNS-008298",
#   "deliverytime": 5,
#   "description": "Zie Omschrijving Webshop",
#   "barcode": "8718375330722",
#   "unlimitedstock": false,
#   "assembled": false,
#   "type": "normal",
#   "weight": 25,
#   "length": null,
#   "width": null,
#   "height": null,
#   "minimum_purchase_quantity": 1,
#   "purchase_in_quantities_of": 1,
#   "hs_code": null,
#   "country_of_origin": null,
#   "show_on_portal": true,
#   "active": true,
#   "created": "2015-12-30 13:36:36",
#   "updated": "2026-01-30 08:21:05",
#   "comment_count": 0,
#   "analysis_abc_classification": null,
#   "analysis_pick_amount_per_day": null,
#   "tags": {
#     "DHL Small": {
#       "idtag": 11964,
#       "title": "DHL Small",
#       "color": "#0000f0",
#       "inherit": true,
#       "textColor": "#FFFFFF"
#     }
#   },
#   "productfields": [
#     {
#       "idproductfield": 1079,
#       "title": "Verzend",
#       "value": "DHL Small"
#     },
#     {
#       "idproductfield": 3223,
#       "title": "VPE",
#       "value": "30"
#     },
#     {
#       "idproductfield": 5156,
#       "title": "Staffel",
#       "value": "90"
#     }
#   ],
#   "images": [
#     "https://files-cdn.picqer.net/1214/43035ef5-3a46-4576-82da-cf5d8d7cf55a/original.jpg",
#     "https://files-cdn.picqer.net/1214/bd531085-cb5f-4844-b248-fdcc56f79f18/original.jpg",
#     "https://files-cdn.picqer.net/1214/bed4aa7a-259e-4508-a462-4ddd74e694c9/original.jpg",
#     "https://files-cdn.picqer.net/1214/fa237ab7-f046-402e-9d69-803c32f78659/original.jpg",
#     "https://files-cdn.picqer.net/1214/4b315b79-86e2-44a8-b9cc-f4f09ee6926d/original.jpg",
#     "https://files-cdn.picqer.net/1214/89c7b745-8094-49b7-81d8-f2092c79ac6e/original.jpg",
#     "https://files-cdn.picqer.net/1214/8a76e856-e836-4fe6-832b-2c8d7f98b061/original.jpg"
#   ],
#   "stock": [
#     {
#       "idwarehouse": 1766,
#       "stock": 15,
#       "reserved": 1,
#       "reservedbackorders": 0,
#       "reservedpicklists": 1,
#       "reservedallocations": 0,
#       "freestock": 14
#     }
#   ],
#   "pricelists": []
# }

# %%
def get_lightspeed_product_weight(variant):
    weight_unit = variant["weightUnit"]

    if weight_unit == "g":
        return variant["weight"] 
    
    if weight_unit == "kg":
        return variant["weight"] * 1000
    
    print(f"Unknown weight unit: {weight_unit}")
    return variant["weight"]

# %%
def get_sending_option(weight):
    if weight < 25:
        return "Briefpost"
    elif weight < 1001:
        return "DHL Small"
    elif weight < 10000:
        return "DPD"
    elif weight < 50000:
        return "DHL XXL"
    elif weight >= 50000:
        return "Speciaal Transport"
    else:
        return "VERZENDTYPE ONBEKEND"

# %%
def parse_delivery_days(data01: str) -> int | None:
    """Extract the first number from a Lightspeed data01 delivery string, e.g. '3-5 dagen' → 3"""
    if not data01:
        return None
    match = re.search(r'\d+', data01)
    return int(match.group()) if match else None

# %%
put_requests = []
all_products = []

while len(all_variants) > 0:
    variant = all_variants.pop()

    url = f"{BASE_URL}/api/v1/products?productcode={variant['sku']}"
    response = requests.get(url, auth=(API_KEY, ""))
    product = response.json()

    if len(product) != 1:
        print(f"Product with SKU {variant['sku']} not found in Picqer, skipping.")
        continue

    product = product[0]  # Get the single product from the list

    all_products.append(product)

    print(json.dumps(product, indent=2))

    product_weight = get_lightspeed_product_weight(variant)
    product_sending_option = get_sending_option(product_weight)
    product_tag = next((tag for tag in tags if tag["title"] == product_sending_option), None)

    if not product_tag:
        print(f"Tag not found for sending option: {product_sending_option}")
        continue

    delivery_days = parse_delivery_days(variant.get("data01", ""))
    delivery_time_text = variant.get("data01", "")

    put_requests.append({
        "id": product["idproduct"],
        "payload": {
            "weight": product_weight,
            "deliverytime": delivery_days,  # built-in Picqer field (integer days)
            "tag": {
                product_sending_option: product_tag
            },
            "productfields": [
                {
                    "idproductfield": send_options_field["idproductfield"],
                    "value": product_sending_option
                },
            ]
        }
    })
# Out:
# {
#   "idproduct": 1822521,
#   "idvatgroup": 3583,
#   "idsupplier": 11409,
#   "productcode": "24327000005",
#   "name": "Benson Multifunctionele bijl - hamer - koevoet - tomahawk stijl - 900 gram - 4 in 1",
#   "price": 7.85,
#   "fixedstockprice": 3.75,
#   "productcode_supplier": "BNS-008044",
#   "deliverytime": 5,
#   "description": "Zie Omschrijving Webshop",
#   "barcode": "8718026589127",
#   "unlimitedstock": false,
#   "assembled": false,
#   "type": "normal",
#   "weight": 2,
#   "length": null,
#   "width": null,
#   "height": null,
#   "minimum_purchase_quantity": 1,
#   "purchase_in_quantities_of": 1,
#   "hs_code": null,
#   "country_of_origin": null,
#   "show_on_portal": true,
#   "active": true,
#   "created": "2015-12-30 13:22:06",
#   "updated": "2026-02-25 00:23:18",
#   "comment_count": 0,
#   "analysis_abc_classification": null,
#   "analysis_pick_amount_per_day": null,
#   "tags": {
#     "Briefpost": {
#       "idtag": 8125,
#       "title": "Briefpost",
#       "color": "#1aa8b0",
#       "inherit": true,
#       "textColor": "#000000"
#     }
#   },
#   "productfields": [
#     {
#       "idproductfield": 1079,
#       "title": "Verzend",
#       "value": "Briefpost"
#     },
#     {
#       "idproductfield": 3223,
#       "title": "VPE",
#       "value": "24/6"
#     },
#     {
#       "idproductfield": 5156,
#       "title": "Staffel",
#       "value": "24"
#     }
#   ],
#   "images": [
#     "https://files-cdn.picqer.net/1214/635dd8d2-674c-4ebb-8d35-0b8840a44091/original.jpg",
#     "https://files-cdn.picqer.net/1214/8b605671-c272-400d-aa35-202b79702091/original.jpg",
#     "https://files-cdn.picqer.net/1214/e82bc837-6d8d-42c7-b971-ba3bf6a4faab/original.jpg",
#     "https://files-cdn.picqer.net/1214/2c919b14-188d-4c8e-9a6c-e296fb38edfa/original.jpg",
#     "https://files-cdn.picqer.net/1214/cd1121ac-0fa8-40d1-9913-80d7dd91163e/original.jpg",
#     "https://files-cdn.picqer.net/1214/7e9a2c1a-9a66-4e01-8c85-6680aced90f8/original.jpg",
#     "https://files-cdn.picqer.net/1214/a51828f1-cfc1-43f3-9a39-3ca494426dc9/original.jpg"
#   ],
#   "stock": [
#     {
#       "idwarehouse": 1766,
#       "stock": 0,
#       "reserved": 0,
#       "reservedbackorders": 0,
#       "reservedpicklists": 0,
#       "reservedallocations": 0,
#       "freestock": 0
#     }
#   ],
#   "pricelists": []
# }
# {
#   "idproduct": 1822518,
#   "idvatgroup": 3583,
#   "idsupplier": 11409,
#   "productcode": "24327000006",
#   "name": "Hofftech Voorhamer - 3 kg hamerkop - 90 cm glasfibersteel - antislip grip - Multi Neck systeem",
#   "price": 25,
#   "fixedstockprice": 11.99,
#   "productcode_supplier": "BNS-006145",
#   "deliverytime": 5,
#   "description": "Zie Omschrijving Webshop",
#   "barcode": "8717729114957",
#   "unlimitedstock": false,
#   "assembled": false,
#   "type": "normal",
#   "weight": 25,
#   "length": null,
#   "width": null,
#   "height": null,
#   "minimum_purchase_quantity": 1,
#   "purchase_in_quantities_of": 1,
#   "hs_code": null,
#   "country_of_origin": null,
#   "show_on_portal": true,
#   "active": true,
#   "created": "2015-12-30 13:22:03",
#   "updated": "2026-02-25 00:22:42",
#   "comment_count": 0,
#   "analysis_abc_classification": "C",
#   "analysis_pick_amount_per_day": "0.036",
#   "tags": {
#     "DHL Small": {
#       "idtag": 11964,
#       "title": "DHL Small",
#       "color": "#0000f0",
#       "inherit": true,
#       "textColor": "#FFFFFF"
#     }
#   },
#   "productfields": [
#     {
#       "idproductfield": 1079,
#       "title": "Verzend",
#       "value": "DHL Small"
#     },
#     {
#       "idproductfield": 3223,
#       "title": "VPE",
#       "value": "6"
#     },
#     {
#       "idproductfield": 5156,
#       "title": "Staffel",
#       "value": "12"
#     }
#   ],
#   "images": [
#     "https://files-cdn.picqer.net/1214/9f0bde09-f812-4239-bb69-5c17b65ee567/original.jpg",
#     "https://files-cdn.picqer.net/1214/7b054863-1362-42ac-a623-85d2218da4dd/original.jpg",
#     "https://files-cdn.picqer.net/1214/594d8d5b-4835-4861-b27b-697d869b879a/original.jpg",
#     "https://files-cdn.picqer.net/1214/8a2c853d-fde5-4c87-b7c2-111467cf9a43/original.jpg",
#     "https://files-cdn.picqer.net/1214/b481d01b-32fe-4680-b718-20886f91a4aa/original.jpg",
#     "https://files-cdn.picqer.net/1214/c2cfe5f1-02fa-4c25-b9b0-40c26a549aea/original.jpg"
#   ],
#   "stock": [
#     {
#       "idwarehouse": 1766,
#       "stock": 0,
#       "reserved": 0,
#       "reservedbackorders": 0,
#       "reservedpicklists": 0,
#       "reservedallocations": 0,
#       "freestock": 0
#     }
#   ],
#   "pricelists": []
# }
# {
#   "idproduct": 1822517,
#   "idvatgroup": 3583,
#   "idsupplier": 11409,
#   "productcode": "24327000007",
#   "name": "Hofftech Bankhamer - Glasfiber Steel - 500 gram - 35 cm - Ergonomisch Handvat",
#   "price": 8.47,
#   "fixedstockprice": 3.99,
#   "productcode_supplier": "BNS-006132",
#   "deliverytime": 5,
#   "description": "Zie Omschrijving Webshop",
#   "barcode": "8717729114827",
#   "unlimitedstock": false,
#   "assembled": false,
#   "type": "normal",
#   "weight": 2,
#   "length": null,
#   "width": null,
#   "height": null,
#   "minimum_purchase_quantity": 1,
#   "purchase_in_quantities_of": 1,
#   "hs_code": null,
#   "country_of_origin": null,
#   "show_on_portal": true,
#   "active": true,
#   "created": "2015-12-30 13:22:03",
#   "updated": "2026-02-25 00:22:42",
#   "comment_count": 0,
#   "analysis_abc_classification": "C",
#   "analysis_pick_amount_per_day": "0.143",
#   "tags": {
#     "Briefpost": {
#       "idtag": 8125,
#       "title": "Briefpost",
#       "color": "#1aa8b0",
#       "inherit": true,
#       "textColor": "#000000"
#     }
#   },
#   "productfields": [
#     {
#       "idproductfield": 1079,
#       "title": "Verzend",
#       "value": "Briefpost"
#     },
#     {
#       "idproductfield": 3223,
#       "title": "VPE",
#       "value": "36/6"
#     },
#     {
#       "idproductfield": 5156,
#       "title": "Staffel",
#       "value": "36"
#     }
#   ],
#   "images": [
#     "https://files-cdn.picqer.net/1214/9dce24c7-3a1c-439d-927d-94e9d5e525a3/original.jpg",
#     "https://files-cdn.picqer.net/1214/10278802-4791-4ad8-b781-5cdcd7c8fef9/original.jpg",
#     "https://files-cdn.picqer.net/1214/b8996ecc-2292-4463-8055-7d8aa4dde07e/original.jpg"
#   ],
#   "stock": [
#     {
#       "idwarehouse": 1766,
#       "stock": 0,
#       "reserved": 0,
#       "reservedbackorders": 0,
#       "reservedpicklists": 0,
#       "reservedallocations": 0,
#       "freestock": 0
#     }
#   ],
#   "pricelists": []
# }
# {
#   "idproduct": 1822516,
#   "idvatgroup": 3583,
#   "idsupplier": 11409,
#   "productcode": "24327000008",
#   "name": "Hofftech Bankhamer - Glasvezel Steel - 2000 gram - 37 cm - Antislip Handvat",
#   "price": 13.64,
#   "fixedstockprice": 6.55,
#   "productcode_supplier": "BNS-006137",
#   "deliverytime": 5,
#   "description": "Zie Omschrijving Webshop",
#   "barcode": "8717729114872",
#   "unlimitedstock": false,
#   "assembled": false,
#   "type": "normal",
#   "weight": 25,
#   "length": null,
#   "width": null,
#   "height": null,
#   "minimum_purchase_quantity": 1,
#   "purchase_in_quantities_of": 1,
#   "hs_code": null,
#   "country_of_origin": null,
#   "show_on_portal": true,
#   "active": true,
#   "created": "2015-12-30 13:22:02",
#   "updated": "2026-02-23 08:57:01",
#   "comment_count": 0,
#   "analysis_abc_classification": null,
#   "analysis_pick_amount_per_day": null,
#   "tags": {
#     "DHL Small": {
#       "idtag": 11964,
#       "title": "DHL Small",
#       "color": "#0000f0",
#       "inherit": true,
#       "textColor": "#FFFFFF"
#     }
#   },
#   "productfields": [
#     {
#       "idproductfield": 1079,
#       "title": "Verzend",
#       "value": "DHL Small"
#     },
#     {
#       "idproductfield": 3223,
#       "title": "VPE",
#       "value": "12/6"
#     },
#     {
#       "idproductfield": 5156,
#       "title": "Staffel",
#       "value": "24"
#     }
#   ],
#   "images": [
#     "https://files-cdn.picqer.net/1214/d0c30905-0f15-4fca-bb57-923f6e63428e/original.jpg",
#     "https://files-cdn.picqer.net/1214/8d042611-5e87-4eec-afa5-65485be920f9/original.jpg",
#     "https://files-cdn.picqer.net/1214/8be3e7c3-541f-4a87-bb2d-87cfcbf4abb7/original.jpg"
#   ],
#   "stock": [
#     {
#       "idwarehouse": 1766,
#       "stock": 1,
#       "reserved": 0,
#       "reservedbackorders": 0,
#       "reservedpicklists": 0,
#       "reservedallocations": 0,
#       "freestock": 1
#     }
#   ],
#   "pricelists": []
# }
# {
#   "idproduct": 1822515,
#   "idvatgroup": 3583,
#   "idsupplier": 11409,
#   "productcode": "24327000009",
#   "name": "Benson Klauwhamer - Hickory houten steel - Antislip greep - 625 gram - 330 mm",
#   "price": 6.82,
#   "fixedstockprice": 3.3,
#   "productcode_supplier": "BNS-002007",
#   "deliverytime": 5,
#   "description": "Zie Omschrijving Webshop",
#   "barcode": "8717729118979",
#   "unlimitedstock": false,
#   "assembled": false,
#   "type": "normal",
#   "weight": 2,
#   "length": null,
#   "width": null,
#   "height": null,
#   "minimum_purchase_quantity": 1,
#   "purchase_in_quantities_of": 1,
#   "hs_code": null,
#   "country_of_origin": null,
#   "show_on_portal": true,
#   "active": true,
#   "created": "2015-12-30 13:22:01",
#   "updated": "2026-01-30 08:20:33",
#   "comment_count": 0,
#   "analysis_abc_classification": null,
#   "analysis_pick_amount_per_day": null,
#   "tags": {
#     "Briefpost": {
#       "idtag": 8125,
#       "title": "Briefpost",
#       "color": "#1aa8b0",
#       "inherit": true,
#       "textColor": "#000000"
#     }
#   },
#   "productfields": [
#     {
#       "idproductfield": 360,
#       "title": "Beschikbaar",
#       "value": "LEVERTIJD"
#     },
#     {
#       "idproductfield": 1079,
#       "title": "Verzend",
#       "value": "Briefpost"
#     },
#     {
#       "idproductfield": 3223,
#       "title": "VPE",
#       "value": "24/6"
#     },
#     {
#       "idproductfield": 5156,
#       "title": "Staffel",
#       "value": "24"
#     }
#   ],
#   "images": [
#     "https://files-cdn.picqer.net/1214/4ad4882a-1dd5-4e83-9a85-7a27f46dc61a/original.jpg",
#     "https://files-cdn.picqer.net/1214/88cb85cd-be0b-4408-838a-63a007599056/original.jpg"
#   ],
#   "stock": [
#     {
#       "idwarehouse": 1766,
#       "stock": 0,
#       "reserved": 0,
#       "reservedbackorders": 0,
#       "reservedpicklists": 0,
#       "reservedallocations": 0,
#       "freestock": 0
#     }
#   ],
#   "pricelists": []
# }
# {
#   "idproduct": 1822514,
#   "idvatgroup": 3583,
#   "idsupplier": 11409,
#   "productcode": "24327000010",
#   "name": "Hofftech Moker - Vuist - Glasvezel antislip steel - Gehard staal - 1 kg - Zwart/rood",
#   "price": 7.85,
#   "fixedstockprice": 3.75,
#   "productcode_supplier": "BNS-006138",
#   "deliverytime": 5,
#   "description": "Zie Omschrijving Webshop",
#   "barcode": "8717729114889",
#   "unlimitedstock": false,
#   "assembled": false,
#   "type": "normal",
#   "weight": 25,
#   "length": null,
#   "width": null,
#   "height": null,
#   "minimum_purchase_quantity": 1,
#   "purchase_in_quantities_of": 1,
#   "hs_code": null,
#   "country_of_origin": null,
#   "show_on_portal": true,
#   "active": true,
#   "created": "2015-12-30 13:22:01",
#   "updated": "2026-02-23 08:56:22",
#   "comment_count": 0,
#   "analysis_abc_classification": null,
#   "analysis_pick_amount_per_day": null,
#   "tags": {
#     "DHL Small": {
#       "idtag": 11964,
#       "title": "DHL Small",
#       "color": "#0000f0",
#       "inherit": true,
#       "textColor": "#FFFFFF"
#     }
#   },
#   "productfields": [
#     {
#       "idproductfield": 1079,
#       "title": "Verzend",
#       "value": "DHL Small"
#     },
#     {
#       "idproductfield": 3223,
#       "title": "VPE",
#       "value": "12/6"
#     },
#     {
#       "idproductfield": 5156,
#       "title": "Staffel",
#       "value": "24"
#     }
#   ],
#   "images": [
#     "https://files-cdn.picqer.net/1214/6e5293c1-1b36-4845-90bf-1f9b1f5dbe81/original.jpg",
#     "https://files-cdn.picqer.net/1214/0a803bce-2a34-4561-b97e-cd06a7c58c79/original.jpg"
#   ],
#   "stock": [
#     {
#       "idwarehouse": 1766,
#       "stock": 0,
#       "reserved": 0,
#       "reservedbackorders": 0,
#       "reservedpicklists": 0,
#       "reservedallocations": 0,
#       "freestock": 0
#     }
#   ],
#   "pricelists": []
# }
# {
#   "idproduct": 1822512,
#   "idvatgroup": 3583,
#   "idsupplier": 11409,
#   "productcode": "24327000012",
#   "name": "Benson Rubberen hamer - \u00d8 90 mm - houten steel - 40 cm - veelzijdig gebruik",
#   "price": 5.99,
#   "fixedstockprice": 2.89,
#   "productcode_supplier": "BNS-002151",
#   "deliverytime": 5,
#   "description": "Zie Omschrijving Webshop",
#   "barcode": "8718026584184",
#   "unlimitedstock": false,
#   "assembled": false,
#   "type": "normal",
#   "weight": 25,
#   "length": null,
#   "width": null,
#   "height": null,
#   "minimum_purchase_quantity": 1,
#   "purchase_in_quantities_of": 1,
#   "hs_code": null,
#   "country_of_origin": null,
#   "show_on_portal": true,
#   "active": true,
#   "created": "2015-12-30 13:22:00",
#   "updated": "2026-01-30 08:20:33",
#   "comment_count": 0,
#   "analysis_abc_classification": null,
#   "analysis_pick_amount_per_day": null,
#   "tags": {
#     "DHL Small": {
#       "idtag": 11964,
#       "title": "DHL Small",
#       "color": "#0000f0",
#       "inherit": true,
#       "textColor": "#FFFFFF"
#     }
#   },
#   "productfields": [
#     {
#       "idproductfield": 1079,
#       "title": "Verzend",
#       "value": "DHL Small"
#     },
#     {
#       "idproductfield": 3223,
#       "title": "VPE",
#       "value": "12/6"
#     },
#     {
#       "idproductfield": 5156,
#       "title": "Staffel",
#       "value": "24"
#     }
#   ],
#   "images": [
#     "https://files-cdn.picqer.net/1214/bf938b2b-31e7-49c5-a602-932403720280/original.jpg",
#     "https://files-cdn.picqer.net/1214/6d5785b2-39b2-48e5-b429-2fa3957295cb/original.jpg"
#   ],
#   "stock": [
#     {
#       "idwarehouse": 1766,
#       "stock": 2,
#       "reserved": 0,
#       "reservedbackorders": 0,
#       "reservedpicklists": 0,
#       "reservedallocations": 0,
#       "freestock": 2
#     }
#   ],
#   "pricelists": []
# }
# {
#   "idproduct": 1822511,
#   "idvatgroup": 3583,
#   "idsupplier": 11409,
#   "productcode": "24327000013",
#   "name": "Benson Rubberen opzetstuk - voor hamers - universeel - zwart - 1 kilo",
#   "price": 3.26,
#   "fixedstockprice": 1.55,
#   "productcode_supplier": "BNS-001090",
#   "deliverytime": 5,
#   "description": "Zie Omschrijving Webshop",
#   "barcode": "8717344990813",
#   "unlimitedstock": false,
#   "assembled": false,
#   "type": "normal",
#   "weight": 25,
#   "length": null,
#   "width": null,
#   "height": null,
#   "minimum_purchase_quantity": 1,
#   "purchase_in_quantities_of": 1,
#   "hs_code": null,
#   "country_of_origin": null,
#   "show_on_portal": true,
#   "active": true,
#   "created": "2015-12-30 13:21:59",
#   "updated": "2026-02-25 00:22:42",
#   "comment_count": 0,
#   "analysis_abc_classification": "C",
#   "analysis_pick_amount_per_day": "0.036",
#   "tags": {
#     "DHL Small": {
#       "idtag": 11964,
#       "title": "DHL Small",
#       "color": "#0000f0",
#       "inherit": true,
#       "textColor": "#FFFFFF"
#     }
#   },
#   "productfields": [
#     {
#       "idproductfield": 1079,
#       "title": "Verzend",
#       "value": "DHL Small"
#     },
#     {
#       "idproductfield": 3223,
#       "title": "VPE",
#       "value": "60/30"
#     },
#     {
#       "idproductfield": 5156,
#       "title": "Staffel",
#       "value": "60"
#     }
#   ],
#   "images": [
#     "https://files-cdn.picqer.net/1214/46daee8a-e49d-4e55-919c-a9eae9e2eb96/original.jpg",
#     "https://files-cdn.picqer.net/1214/38d9ba49-dad8-464d-932d-18bd332c9521/original.jpg",
#     "https://files-cdn.picqer.net/1214/1702719b-c5ec-47e3-890d-bc38507ba881/original.jpg"
#   ],
#   "stock": [
#     {
#       "idwarehouse": 1766,
#       "stock": 4,
#       "reserved": 0,
#       "reservedbackorders": 0,
#       "reservedpicklists": 0,
#       "reservedallocations": 0,
#       "freestock": 4
#     }
#   ],
#   "pricelists": []
# }
# {
#   "idproduct": 1822510,
#   "idvatgroup": 3583,
#   "idsupplier": 11409,
#   "productcode": "24327000014",
#   "name": "Benson Stevige moker - 1 kilo - essenhouten antislipsteel - gehard staal",
#   "price": 8.47,
#   "fixedstockprice": 3.99,
#   "productcode_supplier": "BNS-002161",
#   "deliverytime": 5,
#   "description": "Zie Omschrijving Webshop",
#   "barcode": "8717344990394",
#   "unlimitedstock": false,
#   "assembled": false,
#   "type": "normal",
#   "weight": 25,
#   "length": null,
#   "width": null,
#   "height": null,
#   "minimum_purchase_quantity": 1,
#   "purchase_in_quantities_of": 1,
#   "hs_code": null,
#   "country_of_origin": null,
#   "show_on_portal": true,
#   "active": true,
#   "created": "2015-12-30 13:21:58",
#   "updated": "2026-02-23 08:57:05",
#   "comment_count": 0,
#   "analysis_abc_classification": null,
#   "analysis_pick_amount_per_day": null,
#   "tags": {
#     "DHL Small": {
#       "idtag": 11964,
#       "title": "DHL Small",
#       "color": "#0000f0",
#       "inherit": true,
#       "textColor": "#FFFFFF"
#     }
#   },
#   "productfields": [
#     {
#       "idproductfield": 1079,
#       "title": "Verzend",
#       "value": "DHL Small"
#     },
#     {
#       "idproductfield": 3223,
#       "title": "VPE",
#       "value": "16/4"
#     },
#     {
#       "idproductfield": 5156,
#       "title": "Staffel",
#       "value": "16"
#     }
#   ],
#   "images": [
#     "https://files-cdn.picqer.net/1214/f4076d80-4330-4c3f-b415-1a8d26e807f1/original.jpg",
#     "https://files-cdn.picqer.net/1214/d557ee5c-d1f1-45e2-a3a4-5bb702738e82/original.jpg",
#     "https://files-cdn.picqer.net/1214/265767d1-f019-47cc-971e-816124e6c5b7/original.jpg",
#     "https://files-cdn.picqer.net/1214/f76d221e-ddea-4aac-a33e-09244a5cec55/original.jpg"
#   ],
#   "stock": [
#     {
#       "idwarehouse": 1766,
#       "stock": 0,
#       "reserved": 0,
#       "reservedbackorders": 0,
#       "reservedpicklists": 0,
#       "reservedallocations": 0,
#       "freestock": 0
#     }
#   ],
#   "pricelists": []
# }
# {
#   "idproduct": 1822509,
#   "idvatgroup": 3583,
#   "idsupplier": 11409,
#   "productcode": "24327000015",
#   "name": "Hofftech Bankhamer - Glasvezel Steel - Ergonomische Grip - 300 gram - 27.5 cm",
#   "price": 5.58,
#   "fixedstockprice": 2.7,
#   "productcode_supplier": "BNS-006130",
#   "deliverytime": 5,
#   "description": "Zie Omschrijving Webshop",
#   "barcode": "8717729114803",
#   "unlimitedstock": false,
#   "assembled": false,
#   "type": "normal",
#   "weight": 2,
#   "length": null,
#   "width": null,
#   "height": null,
#   "minimum_purchase_quantity": 1,
#   "purchase_in_quantities_of": 1,
#   "hs_code": null,
#   "country_of_origin": null,
#   "show_on_portal": true,
#   "active": true,
#   "created": "2015-12-30 13:21:58",
#   "updated": "2026-01-30 08:20:34",
#   "comment_count": 0,
#   "analysis_abc_classification": null,
#   "analysis_pick_amount_per_day": null,
#   "tags": {
#     "Briefpost": {
#       "idtag": 8125,
#       "title": "Briefpost",
#       "color": "#1aa8b0",
#       "inherit": true,
#       "textColor": "#000000"
#     }
#   },
#   "productfields": [
#     {
#       "idproductfield": 1079,
#       "title": "Verzend",
#       "value": "Briefpost"
#     },
#     {
#       "idproductfield": 3223,
#       "title": "VPE",
#       "value": "24/12"
#     },
#     {
#       "idproductfield": 5156,
#       "title": "Staffel",
#       "value": "48"
#     }
#   ],
#   "images": [
#     "https://files-cdn.picqer.net/1214/3dc27227-3d0b-4ab3-9408-3d558cfbe97e/original.jpg",
#     "https://files-cdn.picqer.net/1214/5894df83-0a06-41fe-b93d-debae80e640b/original.jpg",
#     "https://files-cdn.picqer.net/1214/8aa84435-30c8-41fa-896d-31f0aba51943/original.jpg"
#   ],
#   "stock": [
#     {
#       "idwarehouse": 1766,
#       "stock": 0,
#       "reserved": 0,
#       "reservedbackorders": 0,
#       "reservedpicklists": 0,
#       "reservedallocations": 0,
#       "freestock": 0
#     }
#   ],
#   "pricelists": []
# }
# {
#   "idproduct": 1822508,
#   "idvatgroup": 3583,
#   "idsupplier": 11409,
#   "productcode": "24327000016",
#   "name": "Benson Rubberen hamer - stalen steel - schokdempend - 30 cm - tegelwerk, houtbewerking en camping",
#   "price": 3.72,
#   "fixedstockprice": 1.75,
#   "productcode_supplier": "BNS-001121",
#   "deliverytime": 5,
#   "description": "Zie Omschrijving Webshop",
#   "barcode": "8717344999205",
#   "unlimitedstock": false,
#   "assembled": false,
#   "type": "normal",
#   "weight": 25,
#   "length": null,
#   "width": null,
#   "height": null,
#   "minimum_purchase_quantity": 1,
#   "purchase_in_quantities_of": 1,
#   "hs_code": null,
#   "country_of_origin": null,
#   "show_on_portal": true,
#   "active": true,
#   "created": "2015-12-30 13:21:57",
#   "updated": "2026-02-23 08:56:35",
#   "comment_count": 0,
#   "analysis_abc_classification": null,
#   "analysis_pick_amount_per_day": null,
#   "tags": {
#     "DHL Small": {
#       "idtag": 11964,
#       "title": "DHL Small",
#       "color": "#0000f0",
#       "inherit": true,
#       "textColor": "#FFFFFF"
#     }
#   },
#   "productfields": [
#     {
#       "idproductfield": 1079,
#       "title": "Verzend",
#       "value": "DHL Small"
#     },
#     {
#       "idproductfield": 3223,
#       "title": "VPE",
#       "value": "48/12"
#     },
#     {
#       "idproductfield": 5156,
#       "title": "Staffel",
#       "value": "48"
#     }
#   ],
#   "images": [
#     "https://files-cdn.picqer.net/1214/3d3a7c5f-232f-4b4b-bef1-37fe80b615f2/original.jpg",
#     "https://files-cdn.picqer.net/1214/cb929e05-289a-490e-812b-089af13be812/original.jpg",
#     "https://files-cdn.picqer.net/1214/0d222c8e-62ec-4022-afa8-ac6bf3939b8c/original.jpg"
#   ],
#   "stock": [
#     {
#       "idwarehouse": 1766,
#       "stock": 0,
#       "reserved": 0,
#       "reservedbackorders": 0,
#       "reservedpicklists": 0,
#       "reservedallocations": 0,
#       "freestock": 0
#     }
#   ],
#   "pricelists": []
# }
# {
#   "idproduct": 1822507,
#   "idvatgroup": 3583,
#   "idsupplier": 11409,
#   "productcode": "24327000017",
#   "name": "Hofftech Timmermanshamer - Magnetische Spijkerhouder - Ergonomische Greep - 900 Gram",
#   "price": 8.22,
#   "fixedstockprice": 3.95,
#   "productcode_supplier": "BNS-006150",
#   "deliverytime": 5,
#   "description": "Zie Omschrijving Webshop",
#   "barcode": "8717729115008",
#   "unlimitedstock": false,
#   "assembled": false,
#   "type": "normal",
#   "weight": 25,
#   "length": null,
#   "width": null,
#   "height": null,
#   "minimum_purchase_quantity": 1,
#   "purchase_in_quantities_of": 1,
#   "hs_code": null,
#   "country_of_origin": null,
#   "show_on_portal": true,
#   "active": true,
#   "created": "2015-12-30 13:21:57",
#   "updated": "2026-02-25 00:23:18",
#   "comment_count": 0,
#   "analysis_abc_classification": null,
#   "analysis_pick_amount_per_day": null,
#   "tags": {
#     "DHL Small": {
#       "idtag": 11964,
#       "title": "DHL Small",
#       "color": "#0000f0",
#       "inherit": true,
#       "textColor": "#FFFFFF"
#     }
#   },
#   "productfields": [
#     {
#       "idproductfield": 1079,
#       "title": "Verzend",
#       "value": "DHL Small"
#     },
#     {
#       "idproductfield": 3223,
#       "title": "VPE",
#       "value": "24/6"
#     },
#     {
#       "idproductfield": 5156,
#       "title": "Staffel",
#       "value": "24"
#     }
#   ],
#   "images": [
#     "https://files-cdn.picqer.net/1214/efd96ece-3e85-43aa-8dc0-ed1c74316bb0/original.jpg",
#     "https://files-cdn.picqer.net/1214/7df690ac-2826-472b-838b-5a4c4884f24d/original.jpg"
#   ],
#   "stock": [
#     {
#       "idwarehouse": 1766,
#       "stock": 0,
#       "reserved": 0,
#       "reservedbackorders": 0,
#       "reservedpicklists": 0,
#       "reservedallocations": 0,
#       "freestock": 0
#     }
#   ],
#   "pricelists": []
# }
# {
#   "idproduct": 1822505,
#   "idvatgroup": 3583,
#   "idsupplier": 11409,
#   "productcode": "24327000018",
#   "name": "Hofftech Rubber/kunststof hamer - vervangbare kop - glasvezel handvat - \u00d8 30 mm",
#   "price": 4.09,
#   "fixedstockprice": 1.95,
#   "productcode_supplier": "BNS-006141",
#   "deliverytime": 5,
#   "description": "Zie Omschrijving Webshop",
#   "barcode": "8717729114919",
#   "unlimitedstock": false,
#   "assembled": false,
#   "type": "normal",
#   "weight": 2,
#   "length": null,
#   "width": null,
#   "height": null,
#   "minimum_purchase_quantity": 1,
#   "purchase_in_quantities_of": 1,
#   "hs_code": null,
#   "country_of_origin": null,
#   "show_on_portal": true,
#   "active": true,
#   "created": "2015-12-30 13:21:55",
#   "updated": "2026-02-25 00:22:21",
#   "comment_count": 0,
#   "analysis_abc_classification": "B",
#   "analysis_pick_amount_per_day": "0.143",
#   "tags": {
#     "Briefpost": {
#       "idtag": 8125,
#       "title": "Briefpost",
#       "color": "#1aa8b0",
#       "inherit": true,
#       "textColor": "#000000"
#     }
#   },
#   "productfields": [
#     {
#       "idproductfield": 360,
#       "title": "Beschikbaar",
#       "value": "LEVERTIJD"
#     },
#     {
#       "idproductfield": 1079,
#       "title": "Verzend",
#       "value": "Briefpost"
#     },
#     {
#       "idproductfield": 3223,
#       "title": "VPE",
#       "value": "36/12"
#     },
#     {
#       "idproductfield": 5156,
#       "title": "Staffel",
#       "value": "30"
#     }
#   ],
#   "images": [
#     "https://files-cdn.picqer.net/1214/7df02114-d4c7-4322-b3e5-aea90c5e51cd/original.jpg",
#     "https://files-cdn.picqer.net/1214/125fed05-9054-43a9-8e61-bd6d74d79c34/original.jpg",
#     "https://files-cdn.picqer.net/1214/ff305807-57c4-43ae-bb7d-3204b57cc206/original.jpg",
#     "https://files-cdn.picqer.net/1214/6b1501b4-b4f2-40f4-8ec6-133d09be2040/original.jpg",
#     "https://files-cdn.picqer.net/1214/fb40a5c3-3592-4690-bb3a-6b5c55456d83/original.jpg"
#   ],
#   "stock": [
#     {
#       "idwarehouse": 1766,
#       "stock": 0,
#       "reserved": 0,
#       "reservedbackorders": 0,
#       "reservedpicklists": 0,
#       "reservedallocations": 0,
#       "freestock": 0
#     }
#   ],
#   "pricelists": []
# }
# {
#   "idproduct": 1822503,
#   "idvatgroup": 3583,
#   "idsupplier": 11409,
#   "productcode": "24327000019",
#   "name": "NIET MEER INKOPEN",
#   "price": 1.24,
#   "fixedstockprice": 0.59,
#   "productcode_supplier": "BNS-002700",
#   "deliverytime": 5,
#   "description": "Zie Omschrijving Webshop",
#   "barcode": "8711517102751",
#   "unlimitedstock": false,
#   "assembled": false,
#   "type": "normal",
#   "weight": 2,
#   "length": null,
#   "width": null,
#   "height": null,
#   "minimum_purchase_quantity": 10,
#   "purchase_in_quantities_of": 10,
#   "hs_code": null,
#   "country_of_origin": null,
#   "show_on_portal": true,
#   "active": true,
#   "created": "2015-12-30 13:21:54",
#   "updated": "2026-02-19 17:14:35",
#   "comment_count": 0,
#   "analysis_abc_classification": null,
#   "analysis_pick_amount_per_day": null,
#   "tags": {
#     "Briefpost": {
#       "idtag": 8125,
#       "title": "Briefpost",
#       "color": "#1aa8b0",
#       "inherit": true,
#       "textColor": "#000000"
#     }
#   },
#   "productfields": [
#     {
#       "idproductfield": 360,
#       "title": "Beschikbaar",
#       "value": "LEVERTIJD"
#     },
#     {
#       "idproductfield": 1079,
#       "title": "Verzend",
#       "value": "Briefpost"
#     },
#     {
#       "idproductfield": 3223,
#       "title": "VPE",
#       "value": "130/10"
#     },
#     {
#       "idproductfield": 5156,
#       "title": "Staffel",
#       "value": "130"
#     }
#   ],
#   "images": [
#     "https://files-cdn.picqer.net/1214/356e8e9f-4628-4bfc-a994-5ef01dda893b/original.jpg",
#     "https://files-cdn.picqer.net/1214/2b0cf7d8-9763-4d0b-a312-34e16cc04453/original.jpg"
#   ],
#   "stock": [
#     {
#       "idwarehouse": 1766,
#       "stock": 0,
#       "reserved": 0,
#       "reservedbackorders": 0,
#       "reservedpicklists": 0,
#       "reservedallocations": 0,
#       "freestock": 0
#     }
#   ],
#   "pricelists": []
# }
# {
#   "idproduct": 1822502,
#   "idvatgroup": 3583,
#   "idsupplier": 11409,
#   "productcode": "24327000020",
#   "name": "Benson Verzinkte spaanplaatschroeven - Torx - \u00d8 4.0 mm x 30 mm - 200 stuks",
#   "price": 4.55,
#   "fixedstockprice": 2.15,
#   "productcode_supplier": "BNS-007896",
#   "deliverytime": 5,
#   "description": "Zie Omschrijving Webshop",
#   "barcode": "8718026588090, 8711517523273",
#   "unlimitedstock": false,
#   "assembled": false,
#   "type": "normal",
#   "weight": 25,
#   "length": null,
#   "width": null,
#   "height": null,
#   "minimum_purchase_quantity": 1,
#   "purchase_in_quantities_of": 1,
#   "hs_code": null,
#   "country_of_origin": null,
#   "show_on_portal": true,
#   "active": true,
#   "created": "2015-12-30 13:21:54",
#   "updated": "2026-02-23 08:57:03",
#   "comment_count": 0,
#   "analysis_abc_classification": null,
#   "analysis_pick_amount_per_day": null,
#   "tags": {
#     "DHL Small": {
#       "idtag": 11964,
#       "title": "DHL Small",
#       "color": "#0000f0",
#       "inherit": true,
#       "textColor": "#FFFFFF"
#     }
#   },
#   "productfields": [
#     {
#       "idproductfield": 360,
#       "title": "Beschikbaar",
#       "value": "LEVERTIJD"
#     },
#     {
#       "idproductfield": 1079,
#       "title": "Verzend",
#       "value": "DHL Small"
#     },
#     {
#       "idproductfield": 3223,
#       "title": "VPE",
#       "value": "24"
#     },
#     {
#       "idproductfield": 5156,
#       "title": "Staffel",
#       "value": "24"
#     }
#   ],
#   "images": [
#     "https://files-cdn.picqer.net/1214/698ae4f4-37c1-4983-9113-725f387c9673/original.jpg",
#     "https://files-cdn.picqer.net/1214/a63b671d-2650-447a-8896-dddb18f79259/original.jpg"
#   ],
#   "stock": [
#     {
#       "idwarehouse": 1766,
#       "stock": 3,
#       "reserved": 0,
#       "reservedbackorders": 0,
#       "reservedpicklists": 0,
#       "reservedallocations": 0,
#       "freestock": 3
#     }
#   ],
#   "pricelists": []
# }
# {
#   "idproduct": 1822501,
#   "idvatgroup": 3583,
#   "idsupplier": 11409,
#   "productcode": "24327000021",
#   "name": "NIET MEER INKOPEN",
#   "price": 1.03,
#   "fixedstockprice": 0.44,
#   "productcode_supplier": "BNS-002708",
#   "deliverytime": 5,
#   "description": "Zie Omschrijving Webshop",
#   "barcode": "8711517112361",
#   "unlimitedstock": false,
#   "assembled": false,
#   "type": "normal",
#   "weight": 2,
#   "length": null,
#   "width": null,
#   "height": null,
#   "minimum_purchase_quantity": 10,
#   "purchase_in_quantities_of": 10,
#   "hs_code": null,
#   "country_of_origin": null,
#   "show_on_portal": true,
#   "active": true,
#   "created": "2015-12-30 13:21:53",
#   "updated": "2026-02-02 13:45:49",
#   "comment_count": 0,
#   "analysis_abc_classification": null,
#   "analysis_pick_amount_per_day": null,
#   "tags": {
#     "Briefpost": {
#       "idtag": 8125,
#       "title": "Briefpost",
#       "color": "#1aa8b0",
#       "inherit": true,
#       "textColor": "#000000"
#     }
#   },
#   "productfields": [
#     {
#       "idproductfield": 1079,
#       "title": "Verzend",
#       "value": "Briefpost"
#     },
#     {
#       "idproductfield": 3223,
#       "title": "VPE",
#       "value": "130/10"
#     },
#     {
#       "idproductfield": 5156,
#       "title": "Staffel",
#       "value": "130"
#     }
#   ],
#   "images": [
#     "https://files-cdn.picqer.net/1214/36833370-188a-4a45-ae37-0375acbe4b7e/original.jpg",
#     "https://files-cdn.picqer.net/1214/9d402b9e-ad52-4805-96aa-7f8afc52f814/original.jpg"
#   ],
#   "stock": [
#     {
#       "idwarehouse": 1766,
#       "stock": 0,
#       "reserved": 0,
#       "reservedbackorders": 0,
#       "reservedpicklists": 0,
#       "reservedallocations": 0,
#       "freestock": 0
#     }
#   ],
#   "pricelists": []
# }
# {
#   "idproduct": 1822499,
#   "idvatgroup": 3583,
#   "idsupplier": 11409,
#   "productcode": "24327000023",
#   "name": "Benson Noodschalm met schroef - verzinkt staal - 10 x 90 mm - snelle kettingreparatie",
#   "price": 2.07,
#   "fixedstockprice": 0.95,
#   "productcode_supplier": "BNS-007233",
#   "deliverytime": 5,
#   "description": "Zie Omschrijving Webshop",
#   "barcode": "8718026583132",
#   "unlimitedstock": false,
#   "assembled": false,
#   "type": "normal",
#   "weight": 2,
#   "length": null,
#   "width": null,
#   "height": null,
#   "minimum_purchase_quantity": 1,
#   "purchase_in_quantities_of": 1,
#   "hs_code": null,
#   "country_of_origin": null,
#   "show_on_portal": true,
#   "active": true,
#   "created": "2015-12-30 13:21:51",
#   "updated": "2026-01-30 08:20:35",
#   "comment_count": 0,
#   "analysis_abc_classification": null,
#   "analysis_pick_amount_per_day": null,
#   "tags": {
#     "Briefpost": {
#       "idtag": 8125,
#       "title": "Briefpost",
#       "color": "#1aa8b0",
#       "inherit": true,
#       "textColor": "#000000"
#     }
#   },
#   "productfields": [
#     {
#       "idproductfield": 1079,
#       "title": "Verzend",
#       "value": "Briefpost"
#     },
#     {
#       "idproductfield": 3223,
#       "title": "VPE",
#       "value": "72/24"
#     },
#     {
#       "idproductfield": 5156,
#       "title": "Staffel",
#       "value": "72"
#     }
#   ],
#   "images": [
#     "https://files-cdn.picqer.net/1214/cd223a03-9dd6-4516-9c34-9e5c6fbe389f/original.jpg",
#     "https://files-cdn.picqer.net/1214/f96c3e02-f3a3-48b3-b71a-9650804642ed/original.jpg",
#     "https://files-cdn.picqer.net/1214/77b3db00-595e-4711-954a-c5c5eb57bd3e/original.jpg"
#   ],
#   "stock": [
#     {
#       "idwarehouse": 1766,
#       "stock": 0,
#       "reserved": 0,
#       "reservedbackorders": 0,
#       "reservedpicklists": 0,
#       "reservedallocations": 0,
#       "freestock": 0
#     }
#   ],
#   "pricelists": []
# }
# {
#   "idproduct": 1822498,
#   "idvatgroup": 3583,
#   "idsupplier": 11409,
#   "productcode": "24327000024",
#   "name": "Benson Snoerclips - Kabelbeheer - 7 mm - Wit - 25 stuks",
#   "price": 0.62,
#   "fixedstockprice": 0.26,
#   "productcode_supplier": "BNS-009431",
#   "deliverytime": 5,
#   "description": "Zie Omschrijving Webshop",
#   "barcode": "8718375339558",
#   "unlimitedstock": false,
#   "assembled": false,
#   "type": "normal",
#   "weight": 2,
#   "length": null,
#   "width": null,
#   "height": null,
#   "minimum_purchase_quantity": 1,
#   "purchase_in_quantities_of": 1,
#   "hs_code": null,
#   "country_of_origin": null,
#   "show_on_portal": true,
#   "active": true,
#   "created": "2015-12-30 13:21:50",
#   "updated": "2026-01-30 08:20:35",
#   "comment_count": 0,
#   "analysis_abc_classification": null,
#   "analysis_pick_amount_per_day": null,
#   "tags": {
#     "Briefpost": {
#       "idtag": 8125,
#       "title": "Briefpost",
#       "color": "#1aa8b0",
#       "inherit": true,
#       "textColor": "#000000"
#     }
#   },
#   "productfields": [
#     {
#       "idproductfield": 1079,
#       "title": "Verzend",
#       "value": "Briefpost"
#     },
#     {
#       "idproductfield": 3223,
#       "title": "VPE",
#       "value": "500/100"
#     },
#     {
#       "idproductfield": 5156,
#       "title": "Staffel",
#       "value": "250"
#     }
#   ],
#   "images": [
#     "https://files-cdn.picqer.net/1214/182b7a97-321b-4597-bcaa-24ce35e89bfa/original.jpg",
#     "https://files-cdn.picqer.net/1214/3addcaad-fb79-40f8-9c03-947fb66d9c61/original.jpg",
#     "https://files-cdn.picqer.net/1214/4031b991-7a23-4e63-bfbc-f6981e917214/original.jpg",
#     "https://files-cdn.picqer.net/1214/64990ca7-48fa-4462-b84c-d53e343f13e8/original.jpg"
#   ],
#   "stock": [
#     {
#       "idwarehouse": 1766,
#       "stock": 0,
#       "reserved": 0,
#       "reservedbackorders": 0,
#       "reservedpicklists": 0,
#       "reservedallocations": 0,
#       "freestock": 0
#     }
#   ],
#   "pricelists": []
# }
# {
#   "idproduct": 1822497,
#   "idvatgroup": 3583,
#   "idsupplier": 11409,
#   "productcode": "24327000025",
#   "name": "Benson Assortimentbox - Bouten en moeren - Kleine afmetingen - 1 set",
#   "price": 2.27,
#   "fixedstockprice": 1.09,
#   "productcode_supplier": "BNS-009565",
#   "deliverytime": 5,
#   "description": "Zie Omschrijving Webshop",
#   "barcode": "8718692620926",
#   "unlimitedstock": false,
#   "assembled": false,
#   "type": "normal",
#   "weight": 2,
#   "length": null,
#   "width": null,
#   "height": null,
#   "minimum_purchase_quantity": 1,
#   "purchase_in_quantities_of": 1,
#   "hs_code": null,
#   "country_of_origin": null,
#   "show_on_portal": true,
#   "active": true,
#   "created": "2015-12-30 13:21:50",
#   "updated": "2026-01-30 08:20:35",
#   "comment_count": 0,
#   "analysis_abc_classification": null,
#   "analysis_pick_amount_per_day": null,
#   "tags": {
#     "Briefpost": {
#       "idtag": 8125,
#       "title": "Briefpost",
#       "color": "#1aa8b0",
#       "inherit": true,
#       "textColor": "#000000"
#     }
#   },
#   "productfields": [
#     {
#       "idproductfield": 360,
#       "title": "Beschikbaar",
#       "value": "LEVERTIJD"
#     },
#     {
#       "idproductfield": 1079,
#       "title": "Verzend",
#       "value": "Briefpost"
#     },
#     {
#       "idproductfield": 3223,
#       "title": "VPE",
#       "value": "96/24"
#     },
#     {
#       "idproductfield": 5156,
#       "title": "Staffel",
#       "value": "24"
#     }
#   ],
#   "images": [
#     "https://files-cdn.picqer.net/1214/52438f84-8193-4d0d-b1a3-3e1e8fba25ad/original.jpg",
#     "https://files-cdn.picqer.net/1214/6f6ca189-6efc-47c8-884c-719cd272130c/original.jpg",
#     "https://files-cdn.picqer.net/1214/a1b64bea-3bb1-46d2-8f65-f843f1d4ff6c/original.jpg"
#   ],
#   "stock": [
#     {
#       "idwarehouse": 1766,
#       "stock": 7,
#       "reserved": 0,
#       "reservedbackorders": 0,
#       "reservedpicklists": 0,
#       "reservedallocations": 0,
#       "freestock": 7
#     }
#   ],
#   "pricelists": []
# }
# {
#   "idproduct": 1822729,
#   "idvatgroup": 3583,
#   "idsupplier": 11409,
#   "productcode": "24327000026",
#   "name": "Benson Complete schroeven- en plugset - 165-delig - verzinkt - diverse maten - assortimentsdoos",
#   "price": 5.17,
#   "fixedstockprice": 2.49,
#   "productcode_supplier": "BNS-008242",
#   "deliverytime": 5,
#   "description": "Zie Omschrijving Webshop",
#   "barcode": "8718375330326, 8715156023002",
#   "unlimitedstock": false,
#   "assembled": false,
#   "type": "normal",
#   "weight": 2,
#   "length": null,
#   "width": null,
#   "height": null,
#   "minimum_purchase_quantity": 1,
#   "purchase_in_quantities_of": 1,
#   "hs_code": null,
#   "country_of_origin": null,
#   "show_on_portal": true,
#   "active": true,
#   "created": "2015-12-30 13:31:38",
#   "updated": "2026-02-18 00:18:48",
#   "comment_count": 0,
#   "analysis_abc_classification": null,
#   "analysis_pick_amount_per_day": null,
#   "tags": {
#     "Briefpost": {
#       "idtag": 8125,
#       "title": "Briefpost",
#       "color": "#1aa8b0",
#       "inherit": true,
#       "textColor": "#000000"
#     }
#   },
#   "productfields": [
#     {
#       "idproductfield": 1079,
#       "title": "Verzend",
#       "value": "Briefpost"
#     },
#     {
#       "idproductfield": 3223,
#       "title": "VPE",
#       "value": "40/20"
#     },
#     {
#       "idproductfield": 5156,
#       "title": "Staffel",
#       "value": "40"
#     }
#   ],
#   "images": [
#     "https://files-cdn.picqer.net/1214/36f6a9f8-f014-4e0d-8a56-fc6b658de252/original.jpg",
#     "https://files-cdn.picqer.net/1214/ae87d6cb-a48e-41d1-beb4-65dd0b026d65/original.jpg",
#     "https://files-cdn.picqer.net/1214/51f0dc2d-3fb3-4a1a-86ff-37badbe1df4c/original.jpg"
#   ],
#   "stock": [
#     {
#       "idwarehouse": 1766,
#       "stock": 0,
#       "reserved": 0,
#       "reservedbackorders": 0,
#       "reservedpicklists": 0,
#       "reservedallocations": 0,
#       "freestock": 0
#     }
#   ],
#   "pricelists": []
# }
# {
#   "idproduct": 1822732,
#   "idvatgroup": 3583,
#   "idsupplier": 11409,
#   "productcode": "24327000028",
#   "name": "NIET MEER INKOPEN",
#   "price": 1.03,
#   "fixedstockprice": 0.49,
#   "productcode_supplier": "BNS-003715",
#   "deliverytime": 5,
#   "description": "Zie Omschrijving Webshop",
#   "barcode": "8719304277507, 2500000103230, 8711517111623",
#   "unlimitedstock": false,
#   "assembled": false,
#   "type": "normal",
#   "weight": 2,
#   "length": null,
#   "width": null,
#   "height": null,
#   "minimum_purchase_quantity": 10,
#   "purchase_in_quantities_of": 10,
#   "hs_code": null,
#   "country_of_origin": null,
#   "show_on_portal": true,
#   "active": true,
#   "created": "2015-12-30 13:31:40",
#   "updated": "2026-02-25 00:23:18",
#   "comment_count": 0,
#   "analysis_abc_classification": null,
#   "analysis_pick_amount_per_day": null,
#   "tags": {
#     "Briefpost": {
#       "idtag": 8125,
#       "title": "Briefpost",
#       "color": "#1aa8b0",
#       "inherit": true,
#       "textColor": "#000000"
#     }
#   },
#   "productfields": [
#     {
#       "idproductfield": 360,
#       "title": "Beschikbaar",
#       "value": "LEVERTIJD"
#     },
#     {
#       "idproductfield": 1079,
#       "title": "Verzend",
#       "value": "Briefpost"
#     },
#     {
#       "idproductfield": 3223,
#       "title": "VPE",
#       "value": "130/10"
#     },
#     {
#       "idproductfield": 5156,
#       "title": "Staffel",
#       "value": "130"
#     },
#     {
#       "idproductfield": 5746,
#       "title": "X",
#       "value": "LET OP: NIET MEER INKOPEN"
#     }
#   ],
#   "images": [
#     "https://files-cdn.picqer.net/1214/68082f01-b9f1-40b1-9597-2b519809c0eb/original.jpg",
#     "https://files-cdn.picqer.net/1214/f384156a-7404-4565-93b7-b74e9baff83f/original.jpg"
#   ],
#   "stock": [
#     {
#       "idwarehouse": 1766,
#       "stock": 0,
#       "reserved": 0,
#       "reservedbackorders": 0,
#       "reservedpicklists": 0,
#       "reservedallocations": 0,
#       "freestock": 0
#     }
#   ],
#   "pricelists": []
# }
# {
#   "idproduct": 1822734,
#   "idvatgroup": 3583,
#   "idsupplier": 11409,
#   "productcode": "24327000029",
#   "name": "Benson Assortimentbox met ringen en moeren - M6, M8, M10 - overzichtelijk en compleet",
#   "price": 2.07,
#   "fixedstockprice": 0.98,
#   "productcode_supplier": "BNS-009560",
#   "deliverytime": 5,
#   "description": "Zie Omschrijving Webshop",
#   "barcode": "8718692620872",
#   "unlimitedstock": false,
#   "assembled": false,
#   "type": "normal",
#   "weight": 2,
#   "length": null,
#   "width": null,
#   "height": null,
#   "minimum_purchase_quantity": 1,
#   "purchase_in_quantities_of": 1,
#   "hs_code": null,
#   "country_of_origin": null,
#   "show_on_portal": true,
#   "active": true,
#   "created": "2015-12-30 13:31:41",
#   "updated": "2026-01-30 08:20:36",
#   "comment_count": 0,
#   "analysis_abc_classification": null,
#   "analysis_pick_amount_per_day": null,
#   "tags": {
#     "Briefpost": {
#       "idtag": 8125,
#       "title": "Briefpost",
#       "color": "#1aa8b0",
#       "inherit": true,
#       "textColor": "#000000"
#     }
#   },
#   "productfields": [
#     {
#       "idproductfield": 1079,
#       "title": "Verzend",
#       "value": "Briefpost"
#     },
#     {
#       "idproductfield": 3223,
#       "title": "VPE",
#       "value": "96/24"
#     },
#     {
#       "idproductfield": 5156,
#       "title": "Staffel",
#       "value": "48"
#     }
#   ],
#   "images": [
#     "https://files-cdn.picqer.net/1214/0bf0d39b-9ed2-40ca-82b0-6d4bb556b8c0/original.jpg",
#     "https://files-cdn.picqer.net/1214/422a59f5-91a7-4136-8cdd-dd5d38296132/original.jpg",
#     "https://files-cdn.picqer.net/1214/f23943ec-c141-4769-b532-3a8861f2a170/original.jpg"
#   ],
#   "stock": [
#     {
#       "idwarehouse": 1766,
#       "stock": 0,
#       "reserved": 0,
#       "reservedbackorders": 0,
#       "reservedpicklists": 0,
#       "reservedallocations": 0,
#       "freestock": 0
#     }
#   ],
#   "pricelists": []
# }
# {
#   "idproduct": 1822735,
#   "idvatgroup": 3583,
#   "idsupplier": 11409,
#   "productcode": "24327000030",
#   "name": "Benson Assortimentsdoos parkerschroeven - verzinkt - 13 maten - 350 stuks - scherpe schroefdraad",
#   "price": 5.37,
#   "fixedstockprice": 2.59,
#   "productcode_supplier": "BNS-008251",
#   "deliverytime": 5,
#   "description": "Zie Omschrijving Webshop",
#   "barcode": "8718375330418",
#   "unlimitedstock": false,
#   "assembled": false,
#   "type": "normal",
#   "weight": 2,
#   "length": null,
#   "width": null,
#   "height": null,
#   "minimum_purchase_quantity": 1,
#   "purchase_in_quantities_of": 1,
#   "hs_code": null,
#   "country_of_origin": null,
#   "show_on_portal": true,
#   "active": true,
#   "created": "2015-12-30 13:31:41",
#   "updated": "2026-01-30 08:20:36",
#   "comment_count": 0,
#   "analysis_abc_classification": null,
#   "analysis_pick_amount_per_day": null,
#   "tags": {
#     "Briefpost": {
#       "idtag": 8125,
#       "title": "Briefpost",
#       "color": "#1aa8b0",
#       "inherit": true,
#       "textColor": "#000000"
#     }
#   },
#   "productfields": [
#     {
#       "idproductfield": 1079,
#       "title": "Verzend",
#       "value": "Briefpost"
#     },
#     {
#       "idproductfield": 3223,
#       "title": "VPE",
#       "value": "20/10"
#     },
#     {
#       "idproductfield": 5156,
#       "title": "Staffel",
#       "value": "40"
#     }
#   ],
#   "images": [
#     "https://files-cdn.picqer.net/1214/bc18fb82-922c-4a6b-90dd-042742e52b09/original.jpg",
#     "https://files-cdn.picqer.net/1214/cf9f04f5-2de9-4501-a2ee-f5c2418669d9/original.jpg",
#     "https://files-cdn.picqer.net/1214/7983751e-fb16-4dd5-b733-4b45bd523a0d/original.jpg"
#   ],
#   "stock": [
#     {
#       "idwarehouse": 1766,
#       "stock": 11,
#       "reserved": 0,
#       "reservedbackorders": 0,
#       "reservedpicklists": 0,
#       "reservedallocations": 0,
#       "freestock": 11
#     }
#   ],
#   "pricelists": []
# }
# {
#   "idproduct": 1822736,
#   "idvatgroup": 3583,
#   "idsupplier": 11409,
#   "productcode": "24327000031",
#   "name": "Benson Verzinkte spaanplaatschroeven - platkop - pozidrive - 3.0 x 16 mm - 200 stuks",
#   "price": 1.86,
#   "fixedstockprice": 0.89,
#   "productcode_supplier": "BNS-001062",
#   "deliverytime": 5,
#   "description": "Zie Omschrijving Webshop",
#   "barcode": "8717729115794, 8711517520333",
#   "unlimitedstock": false,
#   "assembled": false,
#   "type": "normal",
#   "weight": 2,
#   "length": null,
#   "width": null,
#   "height": null,
#   "minimum_purchase_quantity": 1,
#   "purchase_in_quantities_of": 1,
#   "hs_code": null,
#   "country_of_origin": null,
#   "show_on_portal": true,
#   "active": true,
#   "created": "2015-12-30 13:31:42",
#   "updated": "2026-01-30 08:20:36",
#   "comment_count": 0,
#   "analysis_abc_classification": null,
#   "analysis_pick_amount_per_day": null,
#   "tags": {
#     "Briefpost": {
#       "idtag": 8125,
#       "title": "Briefpost",
#       "color": "#1aa8b0",
#       "inherit": true,
#       "textColor": "#000000"
#     }
#   },
#   "productfields": [
#     {
#       "idproductfield": 360,
#       "title": "Beschikbaar",
#       "value": "LEVERTIJD"
#     },
#     {
#       "idproductfield": 1079,
#       "title": "Verzend",
#       "value": "Briefpost"
#     },
#     {
#       "idproductfield": 3223,
#       "title": "VPE",
#       "value": "8"
#     },
#     {
#       "idproductfield": 5156,
#       "title": "Staffel",
#       "value": "80"
#     }
#   ],
#   "images": [
#     "https://files-cdn.picqer.net/1214/058c9a1b-a62f-42d5-b422-f0812dcafeb3/original.jpg",
#     "https://files-cdn.picqer.net/1214/ea24a0fb-d667-43fc-b1d1-564919fb7b93/original.jpg",
#     "https://files-cdn.picqer.net/1214/8b842ea8-1a9e-4e61-b3a2-b3e9840024df/original.jpg",
#     "https://files-cdn.picqer.net/1214/fbee3b52-5d4c-4db1-94cc-3718d5b2028f/original.jpg"
#   ],
#   "stock": [
#     {
#       "idwarehouse": 1766,
#       "stock": 5,
#       "reserved": 0,
#       "reservedbackorders": 0,
#       "reservedpicklists": 0,
#       "reservedallocations": 0,
#       "freestock": 5
#     }
#   ],
#   "pricelists": []
# }
# {
#   "idproduct": 1822738,
#   "idvatgroup": 3583,
#   "idsupplier": 11409,
#   "productcode": "24327000033",
#   "name": "Benson Assortimentsdoos - Parkerschroeven - Verzinkt - 6 maten - 90-delig",
#   "price": 1.49,
#   "fixedstockprice": 0.98,
#   "productcode_supplier": "BNS-009566",
#   "deliverytime": 5,
#   "description": "Zie Omschrijving Webshop",
#   "barcode": "8718692620933",
#   "unlimitedstock": false,
#   "assembled": false,
#   "type": "normal",
#   "weight": 2,
#   "length": null,
#   "width": null,
#   "height": null,
#   "minimum_purchase_quantity": 1,
#   "purchase_in_quantities_of": 1,
#   "hs_code": null,
#   "country_of_origin": null,
#   "show_on_portal": true,
#   "active": true,
#   "created": "2015-12-30 13:31:43",
#   "updated": "2026-02-25 00:22:42",
#   "comment_count": 0,
#   "analysis_abc_classification": "C",
#   "analysis_pick_amount_per_day": "0.036",
#   "tags": {
#     "Briefpost": {
#       "idtag": 8125,
#       "title": "Briefpost",
#       "color": "#1aa8b0",
#       "inherit": true,
#       "textColor": "#000000"
#     }
#   },
#   "productfields": [
#     {
#       "idproductfield": 360,
#       "title": "Beschikbaar",
#       "value": "LEVERTIJD"
#     },
#     {
#       "idproductfield": 1079,
#       "title": "Verzend",
#       "value": "Briefpost"
#     },
#     {
#       "idproductfield": 3223,
#       "title": "VPE",
#       "value": "96/24"
#     },
#     {
#       "idproductfield": 5156,
#       "title": "Staffel",
#       "value": "48 stuks voor \u20ac0,89"
#     },
#     {
#       "idproductfield": 5746,
#       "title": "X",
#       "value": "LET OP: NIET MEER INKOPEN"
#     }
#   ],
#   "images": [
#     "https://files-cdn.picqer.net/1214/85efa818-c7fa-49c9-bb50-cbc00e6e4593/original.jpg",
#     "https://files-cdn.picqer.net/1214/0124770c-d8bb-4410-a3ad-c3c15590a69d/original.jpg"
#   ],
#   "stock": [
#     {
#       "idwarehouse": 1766,
#       "stock": 2,
#       "reserved": 0,
#       "reservedbackorders": 0,
#       "reservedpicklists": 0,
#       "reservedallocations": 0,
#       "freestock": 2
#     }
#   ],
#   "pricelists": []
# }
# {
#   "idproduct": 1822739,
#   "idvatgroup": 3583,
#   "idsupplier": 11409,
#   "productcode": "24327000034",
#   "name": "Deltafix Windhaak met schroefoog - verzinkt - 120 mm - 2-delig",
#   "price": 0.41,
#   "fixedstockprice": 0.2,
#   "productcode_supplier": "BNS-000545",
#   "deliverytime": 5,
#   "description": "Zie Omschrijving Webshop",
#   "barcode": "8711517945532, 8711517732637",
#   "unlimitedstock": false,
#   "assembled": false,
#   "type": "normal",
#   "weight": 2,
#   "length": null,
#   "width": null,
#   "height": null,
#   "minimum_purchase_quantity": 50,
#   "purchase_in_quantities_of": 50,
#   "hs_code": null,
#   "country_of_origin": null,
#   "show_on_portal": true,
#   "active": true,
#   "created": "2015-12-30 13:31:43",
#   "updated": "2026-02-25 00:22:42",
#   "comment_count": 0,
#   "analysis_abc_classification": "C",
#   "analysis_pick_amount_per_day": "0.036",
#   "tags": {
#     "Briefpost": {
# ...
#   "price": 3.1,
#   "fixedstockprice": 1.45,
#   "productcode_supplier": "BNS-001808",
#   "deliverytime": 5,
#   "description": "Zie Omschrijving Webshop",
#   "barcode": "8714892420090, 8718026584139",
#   "unlimitedstock": false,
#   "assembled": false,
#   "type": "normal",
#   "weight": 2,
#   "length": null,
#   "width": null,
#   "height": null,
#   "minimum_purchase_quantity": 1,
#   "purchase_in_quantities_of": 1,
#   "hs_code": null,
#   "country_of_origin": null,
#   "show_on_portal": true,
#   "active": true,
#   "created": "2015-12-30 14:11:20",
#   "updated": "2026-01-30 09:01:00",
#   "comment_count": 0,
#   "analysis_abc_classification": null,
#   "analysis_pick_amount_per_day": null,
#   "tags": {
#     "Briefpost": {
#       "idtag": 8125,
#       "title": "Briefpost",
#       "color": "#1aa8b0",
#       "inherit": true,
#       "textColor": "#000000"
#     }
#   },
#   "productfields": [
#     {
#       "idproductfield": 1079,
#       "title": "Verzend",
#       "value": "Briefpost"
#     },
#     {
#       "idproductfield": 3223,
#       "title": "VPE",
#       "value": "50/10"
#     },
#     {
#       "idproductfield": 5156,
#       "title": "Staffel",
#       "value": "100"
#     }
#   ],
#   "images": [
#     "https://files-cdn.picqer.net/1214/2b9183fe-cbd9-4925-a7f5-e1f190d48191/original.jpg",
#     "https://files-cdn.picqer.net/1214/002cb72b-5912-49b6-8d11-dd7741dd3c64/original.jpg",
#     "https://files-cdn.picqer.net/1214/8cd3808c-49f7-478c-a8f2-3a04901aca88/original.jpg"
#   ],
#   "stock": [
#     {
#       "idwarehouse": 1766,
#       "stock": 10,
#       "reserved": 0,
#       "reservedbackorders": 0,
#       "reservedpicklists": 0,
#       "reservedallocations": 0,
#       "freestock": 10
#     }
#   ],
#   "pricelists": []
# }
# {
#   "idproduct": 1823512,
#   "idvatgroup": 3583,
#   "idsupplier": 11409,
#   "productcode": "24327000526",
#   "name": "Benson Lamellenwiel K40 - Schuurlinnenstructuur - 60 x 20 mm - Hoge materiaalafname",
#   "price": 2.27,
#   "fixedstockprice": 1.1,
#   "productcode_supplier": "BNS-007442",
#   "deliverytime": 5,
#   "description": "Zie Omschrijving Webshop",
#   "barcode": "8718026584924",
#   "unlimitedstock": false,
#   "assembled": false,
#   "type": "normal",
#   "weight": 25,
#   "length": null,
#   "width": null,
#   "height": null,
#   "minimum_purchase_quantity": 1,
#   "purchase_in_quantities_of": 1,
#   "hs_code": null,
#   "country_of_origin": null,
#   "show_on_portal": true,
#   "active": true,
#   "created": "2015-12-30 14:11:21",
#   "updated": "2026-01-30 09:00:52",
#   "comment_count": 0,
#   "analysis_abc_classification": null,
#   "analysis_pick_amount_per_day": null,
#   "tags": {
#     "DHL Small": {
#       "idtag": 11964,
#       "title": "DHL Small",
#       "color": "#0000f0",
#       "inherit": true,
#       "textColor": "#FFFFFF"
#     }
#   },
#   "productfields": [
#     {
#       "idproductfield": 1079,
#       "title": "Verzend",
#       "value": "DHL Small"
#     },
#     {
#       "idproductfield": 3223,
#       "title": "VPE",
#       "value": "100/25"
#     },
#     {
#       "idproductfield": 5156,
#       "title": "Staffel",
#       "value": "100"
#     }
#   ],
#   "images": [
#     "https://files-cdn.picqer.net/1214/4f3f2165-edf2-4270-aed4-8e638e741e65/original.jpg",
#     "https://files-cdn.picqer.net/1214/5739f003-0cf9-46e1-926b-d5844c8e5795/original.jpg",
#     "https://files-cdn.picqer.net/1214/c5414323-d2a6-4b09-bdd7-b70e27f2e3b5/original.jpg",
#     "https://files-cdn.picqer.net/1214/14f5f3b7-5812-4bf2-8780-871e5ecb000a/original.jpg",
#     "https://files-cdn.picqer.net/1214/8028b479-7df2-41d6-9a11-57c14a0cb138/original.jpg",
#     "https://files-cdn.picqer.net/1214/72fc6163-23c2-495e-821e-21b22f988724/original.jpg"
#   ],
#   "stock": [
#     {
#       "idwarehouse": 1766,
#       "stock": 0,
#       "reserved": 0,
#       "reservedbackorders": 0,
#       "reservedpicklists": 0,
#       "reservedallocations": 0,
#       "freestock": 0
#     }
#   ],
#   "pricelists": []
# }
# {
#   "idproduct": 1823513,
#   "idvatgroup": 3583,
#   "idsupplier": 11409,
#   "productcode": "24327000527",
#   "name": "Hofftech Forstnerboor set - 5 delig - Voor strakke en splintervrije gaten - Inclusief opbergkoffer",
#   "price": 11.36,
#   "fixedstockprice": 5.5,
#   "productcode_supplier": "BNS-001678",
#   "deliverytime": 5,
#   "description": "Zie Omschrijving Webshop",
#   "barcode": "8717344993715",
#   "unlimitedstock": false,
#   "assembled": false,
#   "type": "normal",
#   "weight": 25,
#   "length": null,
#   "width": null,
#   "height": null,
#   "minimum_purchase_quantity": 1,
#   "purchase_in_quantities_of": 1,
#   "hs_code": null,
#   "country_of_origin": null,
#   "show_on_portal": true,
#   "active": true,
#   "created": "2015-12-30 14:11:22",
#   "updated": "2026-02-23 08:56:50",
#   "comment_count": 0,
#   "analysis_abc_classification": null,
#   "analysis_pick_amount_per_day": null,
#   "tags": {
#     "DHL Small": {
#       "idtag": 11964,
#       "title": "DHL Small",
#       "color": "#0000f0",
#       "inherit": true,
#       "textColor": "#FFFFFF"
#     }
#   },
#   "productfields": [
#     {
#       "idproductfield": 1079,
#       "title": "Verzend",
#       "value": "DHL Small"
#     },
#     {
#       "idproductfield": 3223,
#       "title": "VPE",
#       "value": "1/10"
#     },
#     {
#       "idproductfield": 5156,
#       "title": "Staffel",
#       "value": "10"
#     }
#   ],
#   "images": [
#     "https://files-cdn.picqer.net/1214/79cc7acc-efcc-4c61-9935-ce0121a41862/original.jpg",
#     "https://files-cdn.picqer.net/1214/28fd6f39-7485-4830-8a2b-80ff66768922/original.jpg",
#     "https://files-cdn.picqer.net/1214/408c742d-8ed4-4834-a63d-e1e0fdaada63/original.jpg",
#     "https://files-cdn.picqer.net/1214/e701e4a3-f89e-4146-988a-8c2ff4b69241/original.jpg",
#     "https://files-cdn.picqer.net/1214/1b093869-0471-4dfe-bcfb-3ad35b981a59/original.jpg",
#     "https://files-cdn.picqer.net/1214/e3c67f8a-45fd-40a6-a048-0ba4b723f931/original.jpg",
#     "https://files-cdn.picqer.net/1214/1ee4971b-ee5d-4ed0-876e-7cba7d34e275/original.jpg",
#     "https://files-cdn.picqer.net/1214/34ab74d3-2d0f-4d43-bcb8-eaab1e74d9c9/original.jpg",
#     "https://files-cdn.picqer.net/1214/6be0d5ca-3b3d-4ee2-a0a1-88cabbcd4257/original.jpg",
#     "https://files-cdn.picqer.net/1214/e569bb44-e149-40a9-b28e-0f920db02322/original.jpg"
#   ],
#   "stock": [
#     {
#       "idwarehouse": 1766,
#       "stock": 0,
#       "reserved": 0,
#       "reservedbackorders": 0,
#       "reservedpicklists": 0,
#       "reservedallocations": 0,
#       "freestock": 0
#     }
#   ],
#   "pricelists": []
# }
# {
#   "idproduct": 1823514,
#   "idvatgroup": 3583,
#   "idsupplier": 11409,
#   "productcode": "24327000528",
#   "name": "Benson Metaalborenset - 13-delig - HSS-staal - 2 t/m 8 mm - Spiraalvormig",
#   "price": 4.92,
#   "fixedstockprice": 2.35,
#   "productcode_supplier": "BNS-001807",
#   "deliverytime": 5,
#   "description": "Zie Omschrijving Webshop",
#   "barcode": "8718026584153",
#   "unlimitedstock": false,
#   "assembled": false,
#   "type": "normal",
#   "weight": 2,
#   "length": null,
#   "width": null,
#   "height": null,
#   "minimum_purchase_quantity": 1,
#   "purchase_in_quantities_of": 1,
#   "hs_code": null,
#   "country_of_origin": null,
#   "show_on_portal": true,
#   "active": true,
#   "created": "2015-12-30 14:11:22",
#   "updated": "2026-02-23 08:57:02",
#   "comment_count": 0,
#   "analysis_abc_classification": null,
#   "analysis_pick_amount_per_day": null,
#   "tags": {
#     "Briefpost": {
#       "idtag": 8125,
#       "title": "Briefpost",
#       "color": "#1aa8b0",
#       "inherit": true,
#       "textColor": "#000000"
#     }
#   },
#   "productfields": [
#     {
#       "idproductfield": 1079,
#       "title": "Verzend",
#       "value": "Briefpost"
#     },
#     {
#       "idproductfield": 3223,
#       "title": "VPE",
#       "value": "100/25"
#     },
#     {
#       "idproductfield": 5156,
#       "title": "Staffel",
#       "value": "100"
#     }
#   ],
#   "images": [
#     "https://files-cdn.picqer.net/1214/fb82f50b-5730-4c66-a477-f4b14d905268/original.jpg",
#     "https://files-cdn.picqer.net/1214/bec681ef-0b9c-41ed-961c-40b04ddb21cc/original.jpg",
#     "https://files-cdn.picqer.net/1214/27de9cb7-304b-4913-9de2-f17ec19f13e8/original.jpg"
#   ],
#   "stock": [
#     {
#       "idwarehouse": 1766,
#       "stock": 0,
#       "reserved": 0,
#       "reservedbackorders": 0,
#       "reservedpicklists": 0,
#       "reservedallocations": 0,
#       "freestock": 0
#     }
#   ],
#   "pricelists": []
# }
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 8
#       5 variant = all_variants.pop()
#       7 url = f"{BASE_URL}/api/v1/products?productcode={variant['sku']}"
# ----> 8 response = requests.get(url, auth=(API_KEY, ""))
#       9 product = response.json()
#      11 if len(product) != 1:
#
# File /usr/lib/python3/dist-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /usr/lib/python3/dist-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /usr/lib/python3/dist-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /usr/lib/python3/dist-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /usr/lib/python3/dist-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:791, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 response_conn = conn if not release_conn else None
#     790 # Make the request on the HTTPConnection object
# --> 791 response = self._make_request(
#     792     conn,
#     793     method,
#     794     url,
#     795     timeout=timeout_obj,
#     796     body=body,
#     797     headers=headers,
#     798     chunked=chunked,
#     799     retries=retries,
#     800     response_conn=response_conn,
#     801     preload_content=preload_content,
#     802     decode_content=decode_content,
#     803     **response_kw,
#     804 )
#     806 # Everything went great!
#     807 clean_exit = True
#
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:497, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     494 # conn.request() calls http.client.*.request, not the method in
#     495 # urllib3.request. It also calls makefile (recv) on the socket.
#     496 try:
# --> 497     conn.request(
#     498         method,
#     499         url,
#     500         body=body,
#     501         headers=headers,
#     502         chunked=chunked,
#     503         preload_content=preload_content,
#     504         decode_content=decode_content,
#     505         enforce_content_length=enforce_content_length,
#     506     )
#     508 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     509 # legitimately able to close the connection after sending a valid response.
#     510 # With this behaviour, the received response is still readable.
#     511 except BrokenPipeError:
#
# File /usr/lib/python3/dist-packages/urllib3/connection.py:395, in HTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     393 for header, value in headers.items():
#     394     self.putheader(header, value)
# --> 395 self.endheaders()
#     397 # If we're given a body we start sending that in chunks.
#     398 if chunks is not None:
#
# File /usr/lib/python3.12/http/client.py:1351, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1349 else:
#    1350     raise CannotSendHeader()
# -> 1351 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File /usr/lib/python3.12/http/client.py:1111, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1109 msg = b"\r\n".join(self._buffer)
#    1110 del self._buffer[:]
# -> 1111 self.send(msg)
#    1113 if message_body is not None:
#    1114
#    1115     # create a consistent interface to message_body
#    1116     if hasattr(message_body, 'read'):
#    1117         # Let file-like take precedence over byte-like.  This
#    1118         # is needed to allow the current position of mmap'ed
#    1119         # files to be taken into account.
#
# File /usr/lib/python3.12/http/client.py:1055, in HTTPConnection.send(self, data)
#    1053 if self.sock is None:
#    1054     if self.auto_open:
# -> 1055         self.connect()
#    1056     else:
#    1057         raise NotConnected()
#
# File /usr/lib/python3/dist-packages/urllib3/connection.py:243, in HTTPConnection.connect(self)
#     242 def connect(self) -> None:
# --> 243     self.sock = self._new_conn()
#     244     if self._tunnel_host:
#     245         # If we're tunneling it means we're connected to our proxy.
#     246         self._has_connected_to_proxy = True
#
# File /usr/lib/python3/dist-packages/urllib3/connection.py:203, in HTTPConnection._new_conn(self)
#     198 """Establish a socket connection and set nodelay settings on it.
#     199
#     200 :return: New socket connection.
#     201 """
#     202 try:
# --> 203     sock = connection.create_connection(
#     204         (self._dns_host, self.port),
#     205         self.timeout,
#     206         source_address=self.source_address,
#     207         socket_options=self.socket_options,
#     208     )
#     209 except socket.gaierror as e:
#     210     raise NameResolutionError(self.host, self, e) from e
#
# File /usr/lib/python3/dist-packages/urllib3/util/connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      57 except UnicodeError:
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ---> 60 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61     af, socktype, proto, canonname, sa = res
#      62     sock = None
#
# File /usr/lib/python3.12/socket.py:963, in getaddrinfo(host, port, family, type, proto, flags)
#     960 # We override this function since we want to translate the numeric family
#     961 # and socket type values to enum constants.
#     962 addrlist = []
# --> 963 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     964     af, socktype, proto, canonname, sa = res
#     965     addrlist.append((_intenum_converter(af, AddressFamily),
#     966                      _intenum_converter(socktype, SocketKind),
#     967                      proto, canonname, sa))
#
# KeyboardInterrupt:

# %%
with open('picqer_products.json', 'w') as f:
    json.dump(all_products, f, indent=2)
